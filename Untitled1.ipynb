# %%
from transformers import BlipProcessor, BlipForConditionalGeneration
import clip
import torch, os, shutil, json
from tqdm import tqdm
from PIL import Image, ImageOps
MAIN_FOLDER = "/content/drive/MyDrive/Colab Notebooks/Maruti"
OUTPUT_BASE = "Maruti"
BLIP_MODEL = "Salesforce/blip-image-captioning-large"
CLIP_MODEL = "ViT-B/32"
device = "cuda" if torch.cuda.is_available() else "cpu"
print("Using device:", device)
processor = BlipProcessor.from_pretrained(BLIP_MODEL)
blip = BlipForConditionalGeneration.from_pretrained(BLIP_MODEL).to(device)
clip_model, clip_preprocess = clip.load(CLIP_MODEL, device=device)
print("Models loaded.\n")
def resize_letterbox(img, target_w=900, target_h=600):
    img_w, img_h = img.size
    scale = min(target_w / img_w, target_h / img_h)

    new_w = int(img_w * scale)
    new_h = int(img_h * scale)

    img_resized = img.resize((new_w, new_h), Image.Resampling.LANCZOS)

    new_img = Image.new("RGB", (target_w, target_h), (0, 0, 0))
    new_img.paste(img_resized, ((target_w - new_w) // 2, (target_h - new_h) // 2))

    return new_img
def load_safe_image(path):
    try:
        img = Image.open(path)

        img = ImageOps.exif_transpose(img)
        img = img.convert("RGB")

        w, h = img.size
        if w < 50 or h < 50:
            return None

        img = resize_letterbox(img, 900, 600)


        return img

    except Exception:
        return None
def is_image_file(filepath):
    try:
        with Image.open(filepath) as img:
            img.verify()
        return True
    except:
        return False
EXTERIOR_KEYWORDS = [
    "exterior","outside","road","side view","front view","rear view",
    "profile","headlight","wheel","grille","engine","hood","roof"
]

INTERIOR_KEYWORDS = [
    "interior","inside","cabin","cockpit","seat","dashboard","steering",
    "display","screen","infotainment","gear","shifter","sunroof"
]

NON_CAR_KEYWORDS = [
    "person","phone","holding","laptop","logo","advertisement",
    "poster","graphic","youtube","instagram"
]



STRICT_LABELS = {
    "Exterior": [
        "Front-view",
        "Rear-view",
        "Left-View",
        "Right-View",
        "Front-Left",
        "Front-Right",
        "Rear-Left",
        "Rear-Right",
        "Car-Roof",
        "Engine-Motor-Bay",
        "Battery(EV-Hybrid)",
        "Exterior-Closeup",
        "Exterior-General"
    ],
    "Interior": [
        "Dashboard",
        "Infotainment-System",
        "Front-seats",
        "Back-seats",
        "Gearbox",
        "Sunroof",
        "Boot-Trunk",
        "Interior-Closeup",
        "Interior-General"
    ]
}
def safe_label(label):
    return label.replace("/", "-").replace(" ", "-")
def build_clip_text_embeds():
    embeds = {}
    for cat in STRICT_LABELS:
        embeds[cat] = {}
        for label in STRICT_LABELS[cat]:
            token = clip.tokenize(label).to(device)
            with torch.no_grad():
                emb = clip_model.encode_text(token)
                emb = emb / emb.norm(dim=-1, keepdim=True)
            embeds[cat][label] = emb
    return embeds
TEXT_EMBEDS = build_clip_text_embeds()
print("CLIP text embeddings ready.\n")
def blip_classify(caption):
    cap = caption.lower()

    if sum(kw in cap for kw in NON_CAR_KEYWORDS) >= 2:
        return "Others"

    interior = sum(kw in cap for kw in INTERIOR_KEYWORDS)
    exterior = sum(kw in cap for kw in EXTERIOR_KEYWORDS)

    if interior == 0 and exterior == 0:
        return "Others"

    return "Interior" if interior > exterior else "Exterior"



def clip_label(image, category):

    img_tensor = clip_preprocess(image).unsqueeze(0).to(device)

    with torch.no_grad():
        img_emb = clip_model.encode_image(img_tensor)
        img_emb = img_emb / img_emb.norm(dim=-1, keepdim=True)

    best_score = -999
    best_label = f"{category}-General"

    for label, txt_emb in TEXT_EMBEDS[category].items():
        score = float((img_emb @ txt_emb.T).cpu().squeeze())
        if score > best_score:
            best_score = score
            best_label = label

    if best_score < 0.22:
        return f"{category}-Closeup"

    return best_label



def process_model(input_path, output_path):

    for folder in ["Exterior", "Interior", "Others"]:
        os.makedirs(os.path.join(output_path, folder), exist_ok=True)

    files = [f for f in os.listdir(input_path)
             if is_image_file(os.path.join(input_path, f))]

    if not files:
        print("  No images found.")
        return None

    results = {"Exterior":0, "Interior":0, "Others":0}
    log = []

    for img_name in tqdm(files, desc="  Classifying", leave=False):

        img_path = os.path.join(input_path, img_name)
        image = load_safe_image(img_path)

        if image is None:
            shutil.copy(img_path, os.path.join(output_path, "Others", f"error_{img_name}"))
            results["Others"] += 1
            continue

        # Step 1 → BLIP caption
        blip_inputs = processor(images=image, return_tensors="pt").to(device)
        blip_output = blip.generate(**blip_inputs, max_length=50)
        caption = processor.decode(blip_output[0], skip_special_tokens=True)

        # Step 2 → BLIP decides category
        coarse = blip_classify(caption)

        if coarse == "Others":
            shutil.copy(img_path, os.path.join(output_path, "Others", img_name))
            results["Others"] += 1
            continue

        # Step 3 → CLIP fine label
        fine = safe_label(clip_label(image, coarse))

        # Step 4 → rename and save
        base, ext = os.path.splitext(img_name)
        if not ext:
            ext = ".jpg"

        new_name = f"{fine}_{base}{ext}"
        dest_path = os.path.join(output_path, coarse, new_name)

        counter = 1
        while os.path.exists(dest_path):
            new_name = f"{fine}_{counter}_{base}{ext}"
            dest_path = os.path.join(output_path, coarse, new_name)
            counter += 1

        shutil.copy(img_path, dest_path)
        results[coarse] += 1

        log.append({
            "original": img_name,
            "caption": caption,
            "coarse": coarse,
            "label": fine,
            "new_filename": new_name
        })

    with open(os.path.join(output_path, "classification_log.json"), "w") as f:
        json.dump(log, f, indent=2)

    return results



print("\nStarting batch classification...\n")

models = [f for f in os.listdir(MAIN_FOLDER)
          if os.path.isdir(os.path.join(MAIN_FOLDER, f))]

all_results = {}

for model in models:
    in_path  = os.path.join(MAIN_FOLDER, model)
    out_path = os.path.join(OUTPUT_BASE, model)

    if os.path.exists(out_path):
        shutil.rmtree(out_path)

    print(f"\nProcessing model: {model}")
    res = process_model(in_path, out_path)

    if res:
        all_results[model] = res
        print(f" → Interior: {res['Interior']}  Exterior: {res['Exterior']}  Others: {res['Others']}")


print("\nDONE.\n")
print("Output saved to:", OUTPUT_BASE)
# Out:
# Using device: cuda
# Models loaded.
#
# CLIP text embeddings ready.
#
#
# Starting batch classification...
#
#
# Processing model: invicto
#  → Interior: 35  Exterior: 7  Others: 97
#
# Processing model: xl6
#  → Interior: 26  Exterior: 9  Others: 92
#
# Processing model: brezza
#   Classifying:  85%|████████▌ | 129/151 [00:45<00:07,  2.92it/s]/usr/local/lib/python3.12/dist-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
#  → Interior: 15  Exterior: 44  Others: 92
#
# Processing model: victoris
#  → Interior: 13  Exterior: 12  Others: 117
#
# Processing model: fronx
#  → Interior: 27  Exterior: 18  Others: 98
#
# Processing model: ciaz
#  → Interior: 4  Exterior: 1  Others: 75
#
# Processing model: dzire
#  → Interior: 15  Exterior: 9  Others: 122
#
# Processing model: ertiga
#  → Interior: 15  Exterior: 16  Others: 111
#
# Processing model: s-presso
#  → Interior: 14  Exterior: 26  Others: 104
#
# Processing model: baleno
#  → Interior: 27  Exterior: 11  Others: 104
#
# Processing model: alto-k10
#  → Interior: 12  Exterior: 7  Others: 119
#
# Processing model: celerio
#  → Interior: 15  Exterior: 13  Others: 117
#
# Processing model: swift
#  → Interior: 33  Exterior: 88  Others: 1447
#
# Processing model: wagon-r
#  → Interior: 8  Exterior: 29  Others: 104
#
# Processing model: eeco
#  → Interior: 8  Exterior: 6  Others: 119
#
# Processing model: ignis
#  → Interior: 11  Exterior: 15  Others: 91
#
# Processing model: e-vitara
#  → Interior: 14  Exterior: 18  Others: 112
#
# DONE.
#
# Output saved to: Maruti

# %%
pip install git+https://github.com/openai/CLIP.git
# Out:
# Collecting git+https://github.com/openai/CLIP.git
#   Cloning https://github.com/openai/CLIP.git to /tmp/pip-req-build-6ow0pwug
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/CLIP.git /tmp/pip-req-build-6ow0pwug
#   Resolved https://github.com/openai/CLIP.git to commit dcba3cb2e2827b402d2701e7e1c7d9fed8a20ef1
#   Preparing metadata (setup.py) ... done
# Collecting ftfy (from clip==1.0)
#   Downloading ftfy-6.3.1-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from clip==1.0) (25.0)
# Requirement already satisfied: regex in /usr/local/lib/python3.12/dist-packages (from clip==1.0) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from clip==1.0) (4.67.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from clip==1.0) (2.8.0+cu126)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from clip==1.0) (0.23.0+cu126)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from ftfy->clip==1.0) (0.2.14)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch->clip==1.0) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch->clip==1.0) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch->clip==1.0) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->clip==1.0) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch->clip==1.0) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->clip==1.0) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch->clip==1.0) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->clip==1.0) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->clip==1.0) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch->clip==1.0) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch->clip==1.0) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch->clip==1.0) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch->clip==1.0) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch->clip==1.0) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch->clip==1.0) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch->clip==1.0) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->clip==1.0) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch->clip==1.0) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->clip==1.0) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch->clip==1.0) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch->clip==1.0) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch->clip==1.0) (3.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from torchvision->clip==1.0) (2.0.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchvision->clip==1.0) (11.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->clip==1.0) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->clip==1.0) (3.0.3)
# Downloading ftfy-6.3.1-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 2.1 MB/s eta 0:00:00
# Building wheels for collected packages: clip
#   Building wheel for clip (setup.py) ... done
#   Created wheel for clip: filename=clip-1.0-py3-none-any.whl size=1369490 sha256=31af8a36fff89e2c8546f3f080bc5fd8bc583ee87c42132db08fdab8896d2729
#   Stored in directory: /tmp/pip-ephem-wheel-cache-mhh0_oz5/wheels/35/3e/df/3d24cbfb3b6a06f17a2bfd7d1138900d4365d9028aa8f6e92f
# Successfully built clip
# Installing collected packages: ftfy, clip
# Successfully installed clip-1.0 ftfy-6.3.1

# %%
# !rm -rf Tata/

# %%
files.download("Tata.zip")

# %%
from google.colab import files
# !zip -r Rolls
.zip Rolls
# Out:
#   adding: Rolls/ (stored 0%)
#   adding: Rolls/spectre/ (stored 0%)
#   adding: Rolls/spectre/Exterior/ (stored 0%)
#   adding: Rolls/spectre/Exterior/Car-Roof_0021-cq5dam.web.1920.webp (deflated 0%)
#   adding: Rolls/spectre/Exterior/Car-Roof_0022-cq5dam.web.1920.jpeg (deflated 0%)
#   adding: Rolls/spectre/Exterior/Car-Roof_0018-cq5dam.web.1920.jpeg (deflated 1%)
#   adding: Rolls/spectre/Exterior/Car-Roof_0045-image.jpg (deflated 3%)
#   adding: Rolls/spectre/Exterior/Car-Roof_0011-cq5dam.web.1920.webp (deflated 2%)
#   adding: Rolls/spectre/Exterior/Rear-view_0023-cq5dam.web.1920.webp (deflated 0%)
#   adding: Rolls/spectre/Exterior/Car-Roof_0010-cq5dam.web.1920.jpeg (deflated 2%)
#   adding: Rolls/spectre/Exterior/Car-Roof_0017-cq5dam.web.1920.webp (deflated 0%)
#   adding: Rolls/spectre/Exterior/Car-Roof_0013-cq5dam.web.1920.webp (deflated 0%)
#   adding: Rolls/spectre/Exterior/Battery(EV-Hybrid)_0024-cq5dam.web.1920.jpeg (deflated 0%)
#   adding: Rolls/spectre/Exterior/Car-Roof_0014-cq5dam.web.1920.jpeg (deflated 0%)
#   adding: Rolls/spectre/Exterior/Rear-view_0009-cq5dam.web.1920.webp (deflated 0%)
#   adding: Rolls/spectre/Exterior/Car-Roof_0012-cq5dam.web.1920.png (deflated 0%)
#   adding: Rolls/spectre/Interior/ (stored 0%)
#   adding: Rolls/spectre/Interior/Back-seats_0034-original.jpg (deflated 1%)
#   adding: Rolls/spectre/Interior/Back-seats_0027-cq5dam.web.1920.webp (deflated 0%)
#   adding: Rolls/spectre/Interior/Back-seats_0028-cq5dam.web.1920.jpeg (deflated 0%)
#   adding: Rolls/spectre/Interior/Back-seats_0033-cq5dam.web.1920.webp (stored 0%)
#   adding: Rolls/spectre/Others/ (stored 0%)
#   adding: Rolls/spectre/Others/0044-favicon.png (deflated 1%)
#   adding: Rolls/spectre/Others/0003-cq5dam.web.1920.jpeg (deflated 0%)
#   adding: Rolls/spectre/Others/0037-RRMC-Single-Twin-Card-SPECTRE-DISCOVER.jpg (deflated 1%)
#   adding: Rolls/spectre/Others/0015-cq5dam.web.1920.webp (deflated 0%)
#   adding: Rolls/spectre/Others/0025-cq5dam.web.1920.webp (deflated 0%)
#   adding: Rolls/spectre/Others/0040-touch-icon-iphone-retina.png (stored 0%)
#   adding: Rolls/spectre/Others/0020-cq5dam.web.1920.jpeg (deflated 1%)
#   adding: Rolls/spectre/Others/0008-cq5dam.web.1920.jpeg (deflated 87%)
#   adding: Rolls/spectre/Others/0041-touch-icon-ipad-retina.png (stored 0%)
#   adding: Rolls/spectre/Others/0036-original (deflated 1%)
#   adding: Rolls/spectre/Others/0031-cq5dam.web.1920.webp (stored 0%)
#   adding: Rolls/spectre/Others/0030-cq5dam.web.1920.jpeg (deflated 10%)
#   adding: Rolls/spectre/Others/0002-cq5dam.web.1920.webp (deflated 0%)
#   adding: Rolls/spectre/Others/0026-cq5dam.web.1920.jpeg (deflated 0%)
#   adding: Rolls/spectre/Others/0032-original (deflated 2%)
#   adding: Rolls/spectre/Others/0005-cq5dam.web.1920.webp (deflated 6%)
#   adding: Rolls/spectre/Others/0035-cq5dam.web.1920.webp (stored 0%)
#   adding: Rolls/spectre/Others/0001-cq5dam.web.1920.jpeg (deflated 0%)
#   adding: Rolls/spectre/Others/0007-cq5dam.web.1920.webp (deflated 76%)
#   adding: Rolls/spectre/Others/0039-touch-icon-ipad.png (stored 0%)
#   adding: Rolls/spectre/Others/0038-apple-touch-icon-iphone.png (stored 0%)
#   adding: Rolls/spectre/Others/0016-cq5dam.web.1920.jpeg (deflated 0%)
#   adding: Rolls/spectre/Others/0006-cq5dam.web.1920.png (deflated 4%)
#   adding: Rolls/spectre/Others/0019-cq5dam.web.1920.webp (deflated 1%)
#   adding: Rolls/spectre/Others/0029-cq5dam.web.1920.webp (deflated 37%)
#   adding: Rolls/spectre/Others/0004-cq5dam.web.1920.webp (deflated 0%)
#   adding: Rolls/spectre/Others/error_0043-flags.png (deflated 0%)
#   adding: Rolls/spectre/classification_log.json (deflated 86%)
#   adding: Rolls/phantom-extended/ (stored 0%)
#   adding: Rolls/phantom-extended/Exterior/ (stored 0%)
#   adding: Rolls/phantom-extended/Exterior/Car-Roof_0009-cq5dam.web.1920.jpeg (deflated 5%)
#   adding: Rolls/phantom-extended/Exterior/Exterior-General_0016-cq5dam.web.1920.webp (deflated 0%)
#   adding: Rolls/phantom-extended/Exterior/Car-Roof_0018-cq5dam.web.1920.webp (deflated 0%)
#   adding: Rolls/phantom-extended/Exterior/Car-Roof_0006-cq5dam.web.1920.webp (deflated 0%)
#   adding: Rolls/phantom-extended/Exterior/Exterior-General_0014-cq5dam.web.1920.webp (deflated 0%)
#   adding: Rolls/phantom-extended/Exterior/Exterior-General_0017-original.jpg (deflated 0%)
#   adding: Rolls/phantom-extended/Exterior/Car-Roof_0004-cq5dam.web.1920.webp (deflated 1%)
#   adding: Rolls/phantom-extended/Exterior/Exterior-General_0015-original.jpg (deflated 0%)
#   adding: Rolls/phantom-extended/Exterior/Car-Roof_0007-cq5dam.web.1920.jpeg (deflated 1%)
#   adding: Rolls/phantom-extended/Exterior/Exterior-General_0001-cq5dam.web.1920.jpeg (deflated 3%)
#   adding: Rolls/phantom-extended/Exterior/Car-Roof_0008-cq5dam.web.1920.webp (stored 0%)
#   adding: Rolls/phantom-extended/Exterior/Exterior-General_0002-cq5dam.web.1920.webp (deflated 0%)
#   adding: Rolls/phantom-extended/Exterior/Car-Roof_0003-cq5dam.web.1920.jpeg (deflated 14%)
#   adding: Rolls/phantom-extended/Exterior/Car-Roof_0019-original.jpg (deflated 1%)
#   adding: Rolls/phantom-extended/Interior/ (stored 0%)
#   adding: Rolls/phantom-extended/Others/ (stored 0%)
#   adding: Rolls/phantom-extended/Others/0012-cq5dam.web.1920.webp (deflated 0%)
#   adding: Rolls/phantom-extended/Others/0023-touch-icon-iphone-retina.png (stored 0%)
#   adding: Rolls/phantom-extended/Others/0005-original (deflated 24%)
#   adding: Rolls/phantom-extended/Others/0025-favicon.png (deflated 1%)
#   adding: Rolls/phantom-extended/Others/0011-cq5dam.web.1920.png (deflated 1%)
#   adding: Rolls/phantom-extended/Others/0022-touch-icon-ipad.png (stored 0%)
#   adding: Rolls/phantom-extended/Others/error_0026-flags.png (deflated 0%)
#   adding: Rolls/phantom-extended/Others/0013-cq5dam.web.1920.jpeg (deflated 10%)
#   adding: Rolls/phantom-extended/Others/0010-cq5dam.web.1920.webp (deflated 3%)
#   adding: Rolls/phantom-extended/Others/0024-touch-icon-ipad-retina.png (stored 0%)
#   adding: Rolls/phantom-extended/Others/0020-PEXT-DISC-16-9.jpg (deflated 2%)
#   adding: Rolls/phantom-extended/Others/0021-apple-touch-icon-iphone.png (stored 0%)
#   adding: Rolls/phantom-extended/classification_log.json (deflated 87%)
#   adding: Rolls/cullinan/ (stored 0%)
#   adding: Rolls/cullinan/Exterior/ (stored 0%)
#   adding: Rolls/cullinan/Exterior/Car-Roof_0005-cq5dam.web.1920.webp (deflated 0%)
#   adding: Rolls/cullinan/Exterior/Car-Roof_0011-cq5dam.web.1920.webp (deflated 1%)
#   adding: Rolls/cullinan/Exterior/Car-Roof_0006-cq5dam.web.1920.jpeg (deflated 0%)
#   adding: Rolls/cullinan/Exterior/Car-Roof_0012-cq5dam.web.1920.jpeg (deflated 2%)
#   adding: Rolls/cullinan/Interior/ (stored 0%)
#   adding: Rolls/cullinan/Others/ (stored 0%)
#   adding: Rolls/cullinan/Others/0001-cq5dam.web.1920.webp (deflated 0%)
#   adding: Rolls/cullinan/Others/0009-cq5dam.web.1920.webp (deflated 0%)
#   adding: Rolls/cullinan/Others/0016-original (deflated 2%)
#   adding: Rolls/cullinan/Others/0015-cq5dam.web.1920.webp (stored 0%)
#   adding: Rolls/cullinan/Others/0008-cq5dam.web.1920.jpeg (deflated 1%)
#   adding: Rolls/cullinan/Others/0023-touch-icon-ipad.png (stored 0%)
#   adding: Rolls/cullinan/Others/0025-touch-icon-ipad-retina.png (stored 0%)
#   adding: Rolls/cullinan/Others/error_0029-s1763718174090 (deflated 9%)
#   adding: Rolls/cullinan/Others/0010-cq5dam.web.1920.jpeg (deflated 0%)
#   adding: Rolls/cullinan/Others/0013-cq5dam.web.1920.webp (deflated 0%)
#   adding: Rolls/cullinan/Others/0002-cq5dam.web.1920.jpeg (deflated 0%)
#   adding: Rolls/cullinan/Others/0007-cq5dam.web.1920.webp (deflated 0%)
#   adding: Rolls/cullinan/Others/0024-touch-icon-iphone-retina.png (stored 0%)
#   adding: Rolls/cullinan/Others/0004-cq5dam.web.1920.jpeg (deflated 0%)
#   adding: Rolls/cullinan/Others/0020-original (deflated 2%)
#   adding: Rolls/cullinan/Others/0018-original (deflated 3%)
#   adding: Rolls/cullinan/Others/0022-apple-touch-icon-iphone.png (stored 0%)
#   adding: Rolls/cullinan/Others/0019-cq5dam.web.1920.webp (stored 0%)
#   adding: Rolls/cullinan/Others/0028-image.jpg (deflated 1%)
#   adding: Rolls/cullinan/Others/error_0030-s1763718174587 (deflated 9%)
#   adding: Rolls/cullinan/Others/0017-cq5dam.web.1920.webp (stored 0%)
#   adding: Rolls/cullinan/Others/0014-cq5dam.web.1920.jpeg (deflated 0%)
#   adding: Rolls/cullinan/Others/0033-favicon.png (deflated 1%)
#   adding: Rolls/cullinan/Others/0021-RRMC-Single-Twin-Card-CSII-DISCOVER.jpg (deflated 1%)
#   adding: Rolls/cullinan/Others/error_0031-flags.png (deflated 0%)
#   adding: Rolls/cullinan/Others/0003-cq5dam.web.1920.webp (deflated 0%)
#   adding: Rolls/cullinan/classification_log.json (deflated 75%)
#   adding: Rolls/black-badge/ (stored 0%)
#   adding: Rolls/black-badge/Exterior/ (stored 0%)
#   adding: Rolls/black-badge/Exterior/Car-Roof_0017-cq5dam.web.2880.webp (deflated 0%)
#   adding: Rolls/black-badge/Exterior/Car-Roof_0018-cq5dam.web.1920.webp (deflated 0%)
#   adding: Rolls/black-badge/Exterior/Car-Roof_0027-original.jpg (deflated 4%)
#   adding: Rolls/black-badge/Exterior/Car-Roof_0016-cq5dam.web.1242.webp (stored 0%)
#   adding: Rolls/black-badge/Exterior/Car-Roof_0014-original.jpg (deflated 1%)
#   adding: Rolls/black-badge/Exterior/Car-Roof_0020-cq5dam.web.1920.webp (deflated 0%)
#   adding: Rolls/black-badge/Exterior/Car-Roof_0026-cq5dam.web.1920.webp (stored 0%)
#   adding: Rolls/black-badge/Exterior/Car-Roof_0019-cq5dam.web.828.webp (stored 0%)
#   adding: Rolls/black-badge/Interior/ (stored 0%)
#   adding: Rolls/black-badge/Interior/Dashboard_0012-cq5dam.web.1920.webp (deflated 1%)
#   adding: Rolls/black-badge/Interior/Infotainment-System_0030-TILE-BB-DISCOVER-TWIN-16_9.jpg (deflated 1%)
#   adding: Rolls/black-badge/Interior/Infotainment-System_0013-cq5dam.web.828.webp (stored 0%)
#   adding: Rolls/black-badge/Interior/Infotainment-System_0010-cq5dam.web.1242.webp (deflated 0%)
#   adding: Rolls/black-badge/Interior/Dashboard_0008-original.jpg (deflated 4%)
#   adding: Rolls/black-badge/Interior/Infotainment-System_0002-cq5dam.web.1920.jpeg (deflated 0%)
#   adding: Rolls/black-badge/Interior/Dashboard_0011-cq5dam.web.2880.webp (deflated 2%)
#   adding: Rolls/black-badge/Interior/Dashboard_0041-image.jpg (deflated 2%)
#   adding: Rolls/black-badge/Others/ (stored 0%)
#   adding: Rolls/black-badge/Others/0001-cq5dam.web.1920.webp (stored 0%)
#   adding: Rolls/black-badge/Others/0039-favicon.png (deflated 1%)
#   adding: Rolls/black-badge/Others/0029-original (deflated 1%)
#   adding: Rolls/black-badge/Others/0033-touch-icon-iphone-retina.png (stored 0%)
#   adding: Rolls/black-badge/Others/0024-cq5dam.web.1920.webp (stored 0%)
#   adding: Rolls/black-badge/Others/0025-original (deflated 7%)
#   adding: Rolls/black-badge/Others/0021-cq5dam.web.1920.jpeg (deflated 0%)
#   adding: Rolls/black-badge/Others/0005-cq5dam.web.1920.webp (deflated 0%)
#   adding: Rolls/black-badge/Others/0028-cq5dam.web.1920.webp (deflated 0%)
#   adding: Rolls/black-badge/Others/0031-apple-touch-icon-iphone.png (stored 0%)
#   adding: Rolls/black-badge/Others/error_0038-flags.png (deflated 0%)
#   adding: Rolls/black-badge/Others/0032-touch-icon-ipad.png (stored 0%)
#   adding: Rolls/black-badge/Others/0006-cq5dam.web.1920.jpeg (deflated 0%)
#   adding: Rolls/black-badge/Others/0004-cq5dam.web.1920.jpeg (deflated 7%)
#   adding: Rolls/black-badge/Others/0022-cq5dam.web.1920.webp (deflated 0%)
#   adding: Rolls/black-badge/Others/0023-cq5dam.web.1920.jpeg (deflated 0%)
#   adding: Rolls/black-badge/Others/0035-image.jpg (deflated 0%)
#   adding: Rolls/black-badge/Others/0034-touch-icon-ipad-retina.png (stored 0%)
#   adding: Rolls/black-badge/Others/0003-cq5dam.web.1920.webp (deflated 3%)
#   adding: Rolls/black-badge/classification_log.json (deflated 85%)
#   adding: Rolls/phantom/ (stored 0%)
#   adding: Rolls/phantom/Exterior/ (stored 0%)
#   adding: Rolls/phantom/Exterior/Car-Roof_0018-cq5dam.web.1920.webp (deflated 0%)
#   adding: Rolls/phantom/Exterior/Car-Roof_0006-cq5dam.web.1920.webp (deflated 0%)
#   adding: Rolls/phantom/Exterior/Car-Roof_0007-cq5dam.web.1920.jpeg (deflated 1%)
#   adding: Rolls/phantom/Exterior/Car-Roof_0019-original.jpg (deflated 1%)
#   adding: Rolls/phantom/Interior/ (stored 0%)
#   adding: Rolls/phantom/Others/ (stored 0%)
#   adding: Rolls/phantom/Others/0034-favicon.png (deflated 1%)
#   adding: Rolls/phantom/Others/0026-touch-icon-ipad.png (stored 0%)
#   adding: Rolls/phantom/Others/0001-cq5dam.web.1920.webp (deflated 5%)
#   adding: Rolls/phantom/Others/0009-cq5dam.web.1920.webp (deflated 1%)
#   adding: Rolls/phantom/Others/0012-cq5dam.web.1920.webp (deflated 0%)
#   adding: Rolls/phantom/Others/0028-touch-icon-ipad-retina.png (stored 0%)
#   adding: Rolls/phantom/Others/0004-cq5dam.web.1920.png (deflated 0%)
#   adding: Rolls/phantom/Others/0005-original (deflated 38%)
#   adding: Rolls/phantom/Others/0030-image.jpg (deflated 1%)
#   adding: Rolls/phantom/Others/0025-apple-touch-icon-iphone.png (stored 0%)
#   adding: Rolls/phantom/Others/0002-cq5dam.web.1920.png (deflated 4%)
#   adding: Rolls/phantom/Others/0010-cq5dam.web.1920.jpeg (deflated 1%)
#   adding: Rolls/phantom/Others/0023-original (deflated 1%)
#   adding: Rolls/phantom/Others/0011-original (deflated 23%)
#   adding: Rolls/phantom/Others/0016-cq5dam.web.1920.webp (deflated 2%)
#   adding: Rolls/phantom/Others/0021-original (deflated 2%)
#   adding: Rolls/phantom/Others/0013-cq5dam.web.1920.jpeg (deflated 1%)
#   adding: Rolls/phantom/Others/0027-touch-icon-iphone-retina.png (stored 0%)
#   adding: Rolls/phantom/Others/0022-cq5dam.web.1920.webp (deflated 0%)
#   adding: Rolls/phantom/Others/0020-cq5dam.web.1920.webp (deflated 0%)
#   adding: Rolls/phantom/Others/0003-original (deflated 1%)
#   adding: Rolls/phantom/Others/0035-image.jpg (deflated 14%)
#   adding: Rolls/phantom/Others/0017-cq5dam.web.1920.jpeg (deflated 1%)
#   adding: Rolls/phantom/Others/0014-cq5dam.web.1920.webp (deflated 1%)
#   adding: Rolls/phantom/Others/0024-phantom-100-properties-16-9.jpg (deflated 3%)
#   adding: Rolls/phantom/Others/0015-cq5dam.web.1920.png (deflated 0%)
#   adding: Rolls/phantom/Others/error_0033-flags.png (deflated 0%)
#   adding: Rolls/phantom/Others/0008-original (deflated 98%)
#   adding: Rolls/phantom/classification_log.json (deflated 78%)
#   adding: Rolls/ghost-extended/ (stored 0%)
#   adding: Rolls/ghost-extended/Exterior/ (stored 0%)
#   adding: Rolls/ghost-extended/Exterior/Battery(EV-Hybrid)_0008-cq5dam.web.1920.jpeg (deflated 3%)
#   adding: Rolls/ghost-extended/Exterior/Exterior-General_0015-cq5dam.web.1920.webp (deflated 0%)
#   adding: Rolls/ghost-extended/Exterior/Battery(EV-Hybrid)_0007-cq5dam.web.1920.webp (deflated 1%)
#   adding: Rolls/ghost-extended/Exterior/Exterior-General_0016-original.jpg (deflated 1%)
#   adding: Rolls/ghost-extended/Interior/ (stored 0%)
#   adding: Rolls/ghost-extended/Interior/Interior-General_0009-cq5dam.web.1920.webp (deflated 0%)
#   adding: Rolls/ghost-extended/Interior/Infotainment-System_0014-original.jpg (deflated 1%)
#   adding: Rolls/ghost-extended/Interior/Interior-General_0010-cq5dam.web.1920.jpeg (deflated 0%)
#   adding: Rolls/ghost-extended/Interior/Interior-General_0013-cq5dam.web.1920.webp (deflated 0%)
#   adding: Rolls/ghost-extended/Others/ (stored 0%)
#   adding: Rolls/ghost-extended/Others/0003-cq5dam.web.1920.jpeg (deflated 1%)
#   adding: Rolls/ghost-extended/Others/0002-cq5dam.web.1920.webp (deflated 0%)
#   adding: Rolls/ghost-extended/Others/0023-touch-icon-ipad-retina.png (stored 0%)
#   adding: Rolls/ghost-extended/Others/0005-cq5dam.web.1920.webp (deflated 8%)
#   adding: Rolls/ghost-extended/Others/0011-cq5dam.web.1920.webp (deflated 0%)
#   adding: Rolls/ghost-extended/Others/0019-TILE-GESII-DISCOVER-TWIN-16_9.jpg (deflated 1%)
#   adding: Rolls/ghost-extended/Others/0020-apple-touch-icon-iphone.png (stored 0%)
#   adding: Rolls/ghost-extended/Others/0001-cq5dam.web.1920.jpeg (deflated 0%)
#   adding: Rolls/ghost-extended/Others/0021-touch-icon-ipad.png (stored 0%)
#   adding: Rolls/ghost-extended/Others/0026-favicon.png (deflated 1%)
#   adding: Rolls/ghost-extended/Others/0022-touch-icon-iphone-retina.png (stored 0%)
#   adding: Rolls/ghost-extended/Others/error_0025-flags.png (deflated 0%)
#   adding: Rolls/ghost-extended/Others/0006-cq5dam.web.1920.png (deflated 4%)
#   adding: Rolls/ghost-extended/Others/0018-original (deflated 3%)
#   adding: Rolls/ghost-extended/Others/0012-cq5dam.web.1920.jpeg (deflated 0%)
#   adding: Rolls/ghost-extended/Others/0017-cq5dam.web.1920.webp (deflated 0%)
#   adding: Rolls/ghost-extended/Others/0004-cq5dam.web.1920.webp (deflated 0%)
#   adding: Rolls/ghost-extended/classification_log.json (deflated 79%)
#   adding: Rolls/ghost/ (stored 0%)
#   adding: Rolls/ghost/Exterior/ (stored 0%)
#   adding: Rolls/ghost/Exterior/Car-Roof_0009-cq5dam.web.1920.webp (deflated 0%)
#   adding: Rolls/ghost/Exterior/Car-Roof_0014-cq5dam.web.1920.png (deflated 0%)
#   adding: Rolls/ghost/Exterior/Car-Roof_0015-cq5dam.web.1920.webp (deflated 0%)
#   adding: Rolls/ghost/Exterior/Car-Roof_0016-cq5dam.web.1920.png (deflated 0%)
#   adding: Rolls/ghost/Exterior/Car-Roof_0008-cq5dam.web.1920.jpeg (deflated 0%)
#   adding: Rolls/ghost/Exterior/Battery(EV-Hybrid)_0002-cq5dam.web.1920.webp (deflated 0%)
#   adding: Rolls/ghost/Exterior/Battery(EV-Hybrid)_0001-cq5dam.web.1920.jpeg (deflated 0%)
#   adding: Rolls/ghost/Exterior/Car-Roof_0010-cq5dam.web.1920.jpeg (deflated 1%)
#   adding: Rolls/ghost/Exterior/Car-Roof_0007-cq5dam.web.1920.webp (deflated 0%)
#   adding: Rolls/ghost/Exterior/Car-Roof_0003-cq5dam.web.1920.png (deflated 0%)
#   adding: Rolls/ghost/Exterior/Exterior-General_0024-TILE-GSII-DISCOVER-TWIN-16_9.jpg (deflated 1%)
#   adding: Rolls/ghost/Exterior/Car-Roof_0004-cq5dam.web.1920.webp (deflated 8%)
#   adding: Rolls/ghost/Exterior/Car-Roof_0013-cq5dam.web.1920.webp (deflated 0%)
#   adding: Rolls/ghost/Interior/ (stored 0%)
#   adding: Rolls/ghost/Others/ (stored 0%)
#   adding: Rolls/ghost/Others/0026-touch-icon-ipad.png (stored 0%)
#   adding: Rolls/ghost/Others/0028-touch-icon-ipad-retina.png (stored 0%)
#   adding: Rolls/ghost/Others/0025-apple-touch-icon-iphone.png (stored 0%)
#   adding: Rolls/ghost/Others/0005-cq5dam.web.1920.webp (deflated 7%)
#   adding: Rolls/ghost/Others/0011-cq5dam.web.1920.webp (deflated 0%)
#   adding: Rolls/ghost/Others/0032-favicon.png (deflated 1%)
#   adding: Rolls/ghost/Others/error_0030-flags.png (deflated 0%)
#   adding: Rolls/ghost/Others/0022-original (deflated 3%)
#   adding: Rolls/ghost/Others/0012-cq5dam.web.1920.png (deflated 0%)
#   adding: Rolls/ghost/Others/0020-original (deflated 1%)
#   adding: Rolls/ghost/Others/0027-touch-icon-iphone-retina.png (stored 0%)
#   adding: Rolls/ghost/Others/0006-cq5dam.web.1920.png (deflated 4%)
#   adding: Rolls/ghost/Others/0018-original (deflated 2%)
#   adding: Rolls/ghost/Others/0019-cq5dam.web.1920.webp (deflated 0%)
#   adding: Rolls/ghost/Others/0017-cq5dam.web.1920.webp (stored 0%)
#   adding: Rolls/ghost/Others/0021-cq5dam.web.1920.webp (deflated 0%)
#   adding: Rolls/ghost/classification_log.json (deflated 84%)

# %%
# !unzip /content/drive/MyDrive/Rolls.zip -d /content/drive/MyDrive/
# Out:
# Archive:  /content/drive/MyDrive/Rolls.zip
#    creating: /content/drive/MyDrive/Rolls/
#    creating: /content/drive/MyDrive/Rolls/spectre/
#    creating: /content/drive/MyDrive/Rolls/spectre/Exterior/
#   inflating: /content/drive/MyDrive/Rolls/spectre/Exterior/Car-Roof_0021-cq5dam.web.1920.webp
#   inflating: /content/drive/MyDrive/Rolls/spectre/Exterior/Car-Roof_0022-cq5dam.web.1920.jpeg
#   inflating: /content/drive/MyDrive/Rolls/spectre/Exterior/Car-Roof_0018-cq5dam.web.1920.jpeg
#   inflating: /content/drive/MyDrive/Rolls/spectre/Exterior/Car-Roof_0045-image.jpg
#   inflating: /content/drive/MyDrive/Rolls/spectre/Exterior/Car-Roof_0011-cq5dam.web.1920.webp
#   inflating: /content/drive/MyDrive/Rolls/spectre/Exterior/Rear-view_0023-cq5dam.web.1920.webp
#   inflating: /content/drive/MyDrive/Rolls/spectre/Exterior/Car-Roof_0010-cq5dam.web.1920.jpeg
#   inflating: /content/drive/MyDrive/Rolls/spectre/Exterior/Car-Roof_0017-cq5dam.web.1920.webp
#   inflating: /content/drive/MyDrive/Rolls/spectre/Exterior/Car-Roof_0013-cq5dam.web.1920.webp
#   inflating: /content/drive/MyDrive/Rolls/spectre/Exterior/Battery(EV-Hybrid)_0024-cq5dam.web.1920.jpeg
#   inflating: /content/drive/MyDrive/Rolls/spectre/Exterior/Car-Roof_0014-cq5dam.web.1920.jpeg
#   inflating: /content/drive/MyDrive/Rolls/spectre/Exterior/Rear-view_0009-cq5dam.web.1920.webp
#   inflating: /content/drive/MyDrive/Rolls/spectre/Exterior/Car-Roof_0012-cq5dam.web.1920.png
#    creating: /content/drive/MyDrive/Rolls/spectre/Interior/
#   inflating: /content/drive/MyDrive/Rolls/spectre/Interior/Back-seats_0034-original.jpg
#   inflating: /content/drive/MyDrive/Rolls/spectre/Interior/Back-seats_0027-cq5dam.web.1920.webp
#   inflating: /content/drive/MyDrive/Rolls/spectre/Interior/Back-seats_0028-cq5dam.web.1920.jpeg
#  extracting: /content/drive/MyDrive/Rolls/spectre/Interior/Back-seats_0033-cq5dam.web.1920.webp
#    creating: /content/drive/MyDrive/Rolls/spectre/Others/
#   inflating: /content/drive/MyDrive/Rolls/spectre/Others/0044-favicon.png
#   inflating: /content/drive/MyDrive/Rolls/spectre/Others/0003-cq5dam.web.1920.jpeg
#   inflating: /content/drive/MyDrive/Rolls/spectre/Others/0037-RRMC-Single-Twin-Card-SPECTRE-DISCOVER.jpg
#   inflating: /content/drive/MyDrive/Rolls/spectre/Others/0015-cq5dam.web.1920.webp
#   inflating: /content/drive/MyDrive/Rolls/spectre/Others/0025-cq5dam.web.1920.webp
#  extracting: /content/drive/MyDrive/Rolls/spectre/Others/0040-touch-icon-iphone-retina.png
#   inflating: /content/drive/MyDrive/Rolls/spectre/Others/0020-cq5dam.web.1920.jpeg
#   inflating: /content/drive/MyDrive/Rolls/spectre/Others/0008-cq5dam.web.1920.jpeg
#  extracting: /content/drive/MyDrive/Rolls/spectre/Others/0041-touch-icon-ipad-retina.png
#   inflating: /content/drive/MyDrive/Rolls/spectre/Others/0036-original
#  extracting: /content/drive/MyDrive/Rolls/spectre/Others/0031-cq5dam.web.1920.webp
#   inflating: /content/drive/MyDrive/Rolls/spectre/Others/0030-cq5dam.web.1920.jpeg
#   inflating: /content/drive/MyDrive/Rolls/spectre/Others/0002-cq5dam.web.1920.webp
#   inflating: /content/drive/MyDrive/Rolls/spectre/Others/0026-cq5dam.web.1920.jpeg
#   inflating: /content/drive/MyDrive/Rolls/spectre/Others/0032-original
#   inflating: /content/drive/MyDrive/Rolls/spectre/Others/0005-cq5dam.web.1920.webp
#  extracting: /content/drive/MyDrive/Rolls/spectre/Others/0035-cq5dam.web.1920.webp
#   inflating: /content/drive/MyDrive/Rolls/spectre/Others/0001-cq5dam.web.1920.jpeg
#   inflating: /content/drive/MyDrive/Rolls/spectre/Others/0007-cq5dam.web.1920.webp
#  extracting: /content/drive/MyDrive/Rolls/spectre/Others/0039-touch-icon-ipad.png
#  extracting: /content/drive/MyDrive/Rolls/spectre/Others/0038-apple-touch-icon-iphone.png
#   inflating: /content/drive/MyDrive/Rolls/spectre/Others/0016-cq5dam.web.1920.jpeg
#   inflating: /content/drive/MyDrive/Rolls/spectre/Others/0006-cq5dam.web.1920.png
#   inflating: /content/drive/MyDrive/Rolls/spectre/Others/0019-cq5dam.web.1920.webp
#   inflating: /content/drive/MyDrive/Rolls/spectre/Others/0029-cq5dam.web.1920.webp
#   inflating: /content/drive/MyDrive/Rolls/spectre/Others/0004-cq5dam.web.1920.webp
#   inflating: /content/drive/MyDrive/Rolls/spectre/Others/error_0043-flags.png
#   inflating: /content/drive/MyDrive/Rolls/spectre/classification_log.json
#    creating: /content/drive/MyDrive/Rolls/phantom-extended/
#    creating: /content/drive/MyDrive/Rolls/phantom-extended/Exterior/
#   inflating: /content/drive/MyDrive/Rolls/phantom-extended/Exterior/Car-Roof_0009-cq5dam.web.1920.jpeg
#   inflating: /content/drive/MyDrive/Rolls/phantom-extended/Exterior/Exterior-General_0016-cq5dam.web.1920.webp
#   inflating: /content/drive/MyDrive/Rolls/phantom-extended/Exterior/Car-Roof_0018-cq5dam.web.1920.webp
#   inflating: /content/drive/MyDrive/Rolls/phantom-extended/Exterior/Car-Roof_0006-cq5dam.web.1920.webp
#   inflating: /content/drive/MyDrive/Rolls/phantom-extended/Exterior/Exterior-General_0014-cq5dam.web.1920.webp
#   inflating: /content/drive/MyDrive/Rolls/phantom-extended/Exterior/Exterior-General_0017-original.jpg
#   inflating: /content/drive/MyDrive/Rolls/phantom-extended/Exterior/Car-Roof_0004-cq5dam.web.1920.webp
#   inflating: /content/drive/MyDrive/Rolls/phantom-extended/Exterior/Exterior-General_0015-original.jpg
#   inflating: /content/drive/MyDrive/Rolls/phantom-extended/Exterior/Car-Roof_0007-cq5dam.web.1920.jpeg
#   inflating: /content/drive/MyDrive/Rolls/phantom-extended/Exterior/Exterior-General_0001-cq5dam.web.1920.jpeg
#  extracting: /content/drive/MyDrive/Rolls/phantom-extended/Exterior/Car-Roof_0008-cq5dam.web.1920.webp
#   inflating: /content/drive/MyDrive/Rolls/phantom-extended/Exterior/Exterior-General_0002-cq5dam.web.1920.webp
#   inflating: /content/drive/MyDrive/Rolls/phantom-extended/Exterior/Car-Roof_0003-cq5dam.web.1920.jpeg
#   inflating: /content/drive/MyDrive/Rolls/phantom-extended/Exterior/Car-Roof_0019-original.jpg
#    creating: /content/drive/MyDrive/Rolls/phantom-extended/Interior/
#    creating: /content/drive/MyDrive/Rolls/phantom-extended/Others/
#   inflating: /content/drive/MyDrive/Rolls/phantom-extended/Others/0012-cq5dam.web.1920.webp
#  extracting: /content/drive/MyDrive/Rolls/phantom-extended/Others/0023-touch-icon-iphone-retina.png
#   inflating: /content/drive/MyDrive/Rolls/phantom-extended/Others/0005-original
#   inflating: /content/drive/MyDrive/Rolls/phantom-extended/Others/0025-favicon.png
#   inflating: /content/drive/MyDrive/Rolls/phantom-extended/Others/0011-cq5dam.web.1920.png
#  extracting: /content/drive/MyDrive/Rolls/phantom-extended/Others/0022-touch-icon-ipad.png
#   inflating: /content/drive/MyDrive/Rolls/phantom-extended/Others/error_0026-flags.png
#   inflating: /content/drive/MyDrive/Rolls/phantom-extended/Others/0013-cq5dam.web.1920.jpeg
#   inflating: /content/drive/MyDrive/Rolls/phantom-extended/Others/0010-cq5dam.web.1920.webp
#  extracting: /content/drive/MyDrive/Rolls/phantom-extended/Others/0024-touch-icon-ipad-retina.png
#   inflating: /content/drive/MyDrive/Rolls/phantom-extended/Others/0020-PEXT-DISC-16-9.jpg
#  extracting: /content/drive/MyDrive/Rolls/phantom-extended/Others/0021-apple-touch-icon-iphone.png
#   inflating: /content/drive/MyDrive/Rolls/phantom-extended/classification_log.json
#    creating: /content/drive/MyDrive/Rolls/cullinan/
#    creating: /content/drive/MyDrive/Rolls/cullinan/Exterior/
#   inflating: /content/drive/MyDrive/Rolls/cullinan/Exterior/Car-Roof_0005-cq5dam.web.1920.webp
#   inflating: /content/drive/MyDrive/Rolls/cullinan/Exterior/Car-Roof_0011-cq5dam.web.1920.webp
#   inflating: /content/drive/MyDrive/Rolls/cullinan/Exterior/Car-Roof_0006-cq5dam.web.1920.jpeg
#   inflating: /content/drive/MyDrive/Rolls/cullinan/Exterior/Car-Roof_0012-cq5dam.web.1920.jpeg
#    creating: /content/drive/MyDrive/Rolls/cullinan/Interior/
#    creating: /content/drive/MyDrive/Rolls/cullinan/Others/
#   inflating: /content/drive/MyDrive/Rolls/cullinan/Others/0001-cq5dam.web.1920.webp
#   inflating: /content/drive/MyDrive/Rolls/cullinan/Others/0009-cq5dam.web.1920.webp
#   inflating: /content/drive/MyDrive/Rolls/cullinan/Others/0016-original
#  extracting: /content/drive/MyDrive/Rolls/cullinan/Others/0015-cq5dam.web.1920.webp
#   inflating: /content/drive/MyDrive/Rolls/cullinan/Others/0008-cq5dam.web.1920.jpeg
#  extracting: /content/drive/MyDrive/Rolls/cullinan/Others/0023-touch-icon-ipad.png
#  extracting: /content/drive/MyDrive/Rolls/cullinan/Others/0025-touch-icon-ipad-retina.png
#   inflating: /content/drive/MyDrive/Rolls/cullinan/Others/error_0029-s1763718174090
#   inflating: /content/drive/MyDrive/Rolls/cullinan/Others/0010-cq5dam.web.1920.jpeg
#   inflating: /content/drive/MyDrive/Rolls/cullinan/Others/0013-cq5dam.web.1920.webp
#   inflating: /content/drive/MyDrive/Rolls/cullinan/Others/0002-cq5dam.web.1920.jpeg
#   inflating: /content/drive/MyDrive/Rolls/cullinan/Others/0007-cq5dam.web.1920.webp
#  extracting: /content/drive/MyDrive/Rolls/cullinan/Others/0024-touch-icon-iphone-retina.png
#   inflating: /content/drive/MyDrive/Rolls/cullinan/Others/0004-cq5dam.web.1920.jpeg
#   inflating: /content/drive/MyDrive/Rolls/cullinan/Others/0020-original
#   inflating: /content/drive/MyDrive/Rolls/cullinan/Others/0018-original
#  extracting: /content/drive/MyDrive/Rolls/cullinan/Others/0022-apple-touch-icon-iphone.png
#  extracting: /content/drive/MyDrive/Rolls/cullinan/Others/0019-cq5dam.web.1920.webp
#   inflating: /content/drive/MyDrive/Rolls/cullinan/Others/0028-image.jpg
#   inflating: /content/drive/MyDrive/Rolls/cullinan/Others/error_0030-s1763718174587
#  extracting: /content/drive/MyDrive/Rolls/cullinan/Others/0017-cq5dam.web.1920.webp
#   inflating: /content/drive/MyDrive/Rolls/cullinan/Others/0014-cq5dam.web.1920.jpeg
#   inflating: /content/drive/MyDrive/Rolls/cullinan/Others/0033-favicon.png
#   inflating: /content/drive/MyDrive/Rolls/cullinan/Others/0021-RRMC-Single-Twin-Card-CSII-DISCOVER.jpg
#   inflating: /content/drive/MyDrive/Rolls/cullinan/Others/error_0031-flags.png
#   inflating: /content/drive/MyDrive/Rolls/cullinan/Others/0003-cq5dam.web.1920.webp
#   inflating: /content/drive/MyDrive/Rolls/cullinan/classification_log.json
#    creating: /content/drive/MyDrive/Rolls/black-badge/
#    creating: /content/drive/MyDrive/Rolls/black-badge/Exterior/
#   inflating: /content/drive/MyDrive/Rolls/black-badge/Exterior/Car-Roof_0017-cq5dam.web.2880.webp
#   inflating: /content/drive/MyDrive/Rolls/black-badge/Exterior/Car-Roof_0018-cq5dam.web.1920.webp
#   inflating: /content/drive/MyDrive/Rolls/black-badge/Exterior/Car-Roof_0027-original.jpg
#  extracting: /content/drive/MyDrive/Rolls/black-badge/Exterior/Car-Roof_0016-cq5dam.web.1242.webp
#   inflating: /content/drive/MyDrive/Rolls/black-badge/Exterior/Car-Roof_0014-original.jpg
#   inflating: /content/drive/MyDrive/Rolls/black-badge/Exterior/Car-Roof_0020-cq5dam.web.1920.webp
#  extracting: /content/drive/MyDrive/Rolls/black-badge/Exterior/Car-Roof_0026-cq5dam.web.1920.webp
#  extracting: /content/drive/MyDrive/Rolls/black-badge/Exterior/Car-Roof_0019-cq5dam.web.828.webp
#    creating: /content/drive/MyDrive/Rolls/black-badge/Interior/
#   inflating: /content/drive/MyDrive/Rolls/black-badge/Interior/Dashboard_0012-cq5dam.web.1920.webp
#   inflating: /content/drive/MyDrive/Rolls/black-badge/Interior/Infotainment-System_0030-TILE-BB-DISCOVER-TWIN-16_9.jpg
#  extracting: /content/drive/MyDrive/Rolls/black-badge/Interior/Infotainment-System_0013-cq5dam.web.828.webp
#   inflating: /content/drive/MyDrive/Rolls/black-badge/Interior/Infotainment-System_0010-cq5dam.web.1242.webp
#   inflating: /content/drive/MyDrive/Rolls/black-badge/Interior/Dashboard_0008-original.jpg
#   inflating: /content/drive/MyDrive/Rolls/black-badge/Interior/Infotainment-System_0002-cq5dam.web.1920.jpeg
#   inflating: /content/drive/MyDrive/Rolls/black-badge/Interior/Dashboard_0011-cq5dam.web.2880.webp
#   inflating: /content/drive/MyDrive/Rolls/black-badge/Interior/Dashboard_0041-image.jpg
#    creating: /content/drive/MyDrive/Rolls/black-badge/Others/
#  extracting: /content/drive/MyDrive/Rolls/black-badge/Others/0001-cq5dam.web.1920.webp
#   inflating: /content/drive/MyDrive/Rolls/black-badge/Others/0039-favicon.png
#   inflating: /content/drive/MyDrive/Rolls/black-badge/Others/0029-original
#  extracting: /content/drive/MyDrive/Rolls/black-badge/Others/0033-touch-icon-iphone-retina.png
#  extracting: /content/drive/MyDrive/Rolls/black-badge/Others/0024-cq5dam.web.1920.webp
#   inflating: /content/drive/MyDrive/Rolls/black-badge/Others/0025-original
#   inflating: /content/drive/MyDrive/Rolls/black-badge/Others/0021-cq5dam.web.1920.jpeg
#   inflating: /content/drive/MyDrive/Rolls/black-badge/Others/0005-cq5dam.web.1920.webp
#   inflating: /content/drive/MyDrive/Rolls/black-badge/Others/0028-cq5dam.web.1920.webp
#  extracting: /content/drive/MyDrive/Rolls/black-badge/Others/0031-apple-touch-icon-iphone.png
#   inflating: /content/drive/MyDrive/Rolls/black-badge/Others/error_0038-flags.png
#  extracting: /content/drive/MyDrive/Rolls/black-badge/Others/0032-touch-icon-ipad.png
#   inflating: /content/drive/MyDrive/Rolls/black-badge/Others/0006-cq5dam.web.1920.jpeg
#   inflating: /content/drive/MyDrive/Rolls/black-badge/Others/0004-cq5dam.web.1920.jpeg
#   inflating: /content/drive/MyDrive/Rolls/black-badge/Others/0022-cq5dam.web.1920.webp
#   inflating: /content/drive/MyDrive/Rolls/black-badge/Others/0023-cq5dam.web.1920.jpeg
#   inflating: /content/drive/MyDrive/Rolls/black-badge/Others/0035-image.jpg
#  extracting: /content/drive/MyDrive/Rolls/black-badge/Others/0034-touch-icon-ipad-retina.png
#   inflating: /content/drive/MyDrive/Rolls/black-badge/Others/0003-cq5dam.web.1920.webp
#   inflating: /content/drive/MyDrive/Rolls/black-badge/classification_log.json
#    creating: /content/drive/MyDrive/Rolls/phantom/
#    creating: /content/drive/MyDrive/Rolls/phantom/Exterior/
#   inflating: /content/drive/MyDrive/Rolls/phantom/Exterior/Car-Roof_0018-cq5dam.web.1920.webp
#   inflating: /content/drive/MyDrive/Rolls/phantom/Exterior/Car-Roof_0006-cq5dam.web.1920.webp
#   inflating: /content/drive/MyDrive/Rolls/phantom/Exterior/Car-Roof_0007-cq5dam.web.1920.jpeg
#   inflating: /content/drive/MyDrive/Rolls/phantom/Exterior/Car-Roof_0019-original.jpg
#    creating: /content/drive/MyDrive/Rolls/phantom/Interior/
#    creating: /content/drive/MyDrive/Rolls/phantom/Others/
#   inflating: /content/drive/MyDrive/Rolls/phantom/Others/0034-favicon.png
#  extracting: /content/drive/MyDrive/Rolls/phantom/Others/0026-touch-icon-ipad.png
#   inflating: /content/drive/MyDrive/Rolls/phantom/Others/0001-cq5dam.web.1920.webp
#   inflating: /content/drive/MyDrive/Rolls/phantom/Others/0009-cq5dam.web.1920.webp
#   inflating: /content/drive/MyDrive/Rolls/phantom/Others/0012-cq5dam.web.1920.webp
#  extracting: /content/drive/MyDrive/Rolls/phantom/Others/0028-touch-icon-ipad-retina.png
#   inflating: /content/drive/MyDrive/Rolls/phantom/Others/0004-cq5dam.web.1920.png
#   inflating: /content/drive/MyDrive/Rolls/phantom/Others/0005-original
#   inflating: /content/drive/MyDrive/Rolls/phantom/Others/0030-image.jpg
#  extracting: /content/drive/MyDrive/Rolls/phantom/Others/0025-apple-touch-icon-iphone.png
#   inflating: /content/drive/MyDrive/Rolls/phantom/Others/0002-cq5dam.web.1920.png
#   inflating: /content/drive/MyDrive/Rolls/phantom/Others/0010-cq5dam.web.1920.jpeg
#   inflating: /content/drive/MyDrive/Rolls/phantom/Others/0023-original
#   inflating: /content/drive/MyDrive/Rolls/phantom/Others/0011-original
#   inflating: /content/drive/MyDrive/Rolls/phantom/Others/0016-cq5dam.web.1920.webp
#   inflating: /content/drive/MyDrive/Rolls/phantom/Others/0021-original
#   inflating: /content/drive/MyDrive/Rolls/phantom/Others/0013-cq5dam.web.1920.jpeg
#  extracting: /content/drive/MyDrive/Rolls/phantom/Others/0027-touch-icon-iphone-retina.png
#   inflating: /content/drive/MyDrive/Rolls/phantom/Others/0022-cq5dam.web.1920.webp
#   inflating: /content/drive/MyDrive/Rolls/phantom/Others/0020-cq5dam.web.1920.webp
#   inflating: /content/drive/MyDrive/Rolls/phantom/Others/0003-original
#   inflating: /content/drive/MyDrive/Rolls/phantom/Others/0035-image.jpg
#   inflating: /content/drive/MyDrive/Rolls/phantom/Others/0017-cq5dam.web.1920.jpeg
#   inflating: /content/drive/MyDrive/Rolls/phantom/Others/0014-cq5dam.web.1920.webp
#   inflating: /content/drive/MyDrive/Rolls/phantom/Others/0024-phantom-100-properties-16-9.jpg
#   inflating: /content/drive/MyDrive/Rolls/phantom/Others/0015-cq5dam.web.1920.png
#   inflating: /content/drive/MyDrive/Rolls/phantom/Others/error_0033-flags.png
#   inflating: /content/drive/MyDrive/Rolls/phantom/Others/0008-original
#   inflating: /content/drive/MyDrive/Rolls/phantom/classification_log.json
#    creating: /content/drive/MyDrive/Rolls/ghost-extended/
#    creating: /content/drive/MyDrive/Rolls/ghost-extended/Exterior/
#   inflating: /content/drive/MyDrive/Rolls/ghost-extended/Exterior/Battery(EV-Hybrid)_0008-cq5dam.web.1920.jpeg
#   inflating: /content/drive/MyDrive/Rolls/ghost-extended/Exterior/Exterior-General_0015-cq5dam.web.1920.webp
#   inflating: /content/drive/MyDrive/Rolls/ghost-extended/Exterior/Battery(EV-Hybrid)_0007-cq5dam.web.1920.webp
#   inflating: /content/drive/MyDrive/Rolls/ghost-extended/Exterior/Exterior-General_0016-original.jpg
#    creating: /content/drive/MyDrive/Rolls/ghost-extended/Interior/
#   inflating: /content/drive/MyDrive/Rolls/ghost-extended/Interior/Interior-General_0009-cq5dam.web.1920.webp
#   inflating: /content/drive/MyDrive/Rolls/ghost-extended/Interior/Infotainment-System_0014-original.jpg
#   inflating: /content/drive/MyDrive/Rolls/ghost-extended/Interior/Interior-General_0010-cq5dam.web.1920.jpeg
#   inflating: /content/drive/MyDrive/Rolls/ghost-extended/Interior/Interior-General_0013-cq5dam.web.1920.webp
#    creating: /content/drive/MyDrive/Rolls/ghost-extended/Others/
#   inflating: /content/drive/MyDrive/Rolls/ghost-extended/Others/0003-cq5dam.web.1920.jpeg
#   inflating: /content/drive/MyDrive/Rolls/ghost-extended/Others/0002-cq5dam.web.1920.webp
#  extracting: /content/drive/MyDrive/Rolls/ghost-extended/Others/0023-touch-icon-ipad-retina.png
#   inflating: /content/drive/MyDrive/Rolls/ghost-extended/Others/0005-cq5dam.web.1920.webp
#   inflating: /content/drive/MyDrive/Rolls/ghost-extended/Others/0011-cq5dam.web.1920.webp
#   inflating: /content/drive/MyDrive/Rolls/ghost-extended/Others/0019-TILE-GESII-DISCOVER-TWIN-16_9.jpg
#  extracting: /content/drive/MyDrive/Rolls/ghost-extended/Others/0020-apple-touch-icon-iphone.png
#   inflating: /content/drive/MyDrive/Rolls/ghost-extended/Others/0001-cq5dam.web.1920.jpeg
#  extracting: /content/drive/MyDrive/Rolls/ghost-extended/Others/0021-touch-icon-ipad.png
#   inflating: /content/drive/MyDrive/Rolls/ghost-extended/Others/0026-favicon.png
#  extracting: /content/drive/MyDrive/Rolls/ghost-extended/Others/0022-touch-icon-iphone-retina.png
#   inflating: /content/drive/MyDrive/Rolls/ghost-extended/Others/error_0025-flags.png
#   inflating: /content/drive/MyDrive/Rolls/ghost-extended/Others/0006-cq5dam.web.1920.png
#   inflating: /content/drive/MyDrive/Rolls/ghost-extended/Others/0018-original
#   inflating: /content/drive/MyDrive/Rolls/ghost-extended/Others/0012-cq5dam.web.1920.jpeg
#   inflating: /content/drive/MyDrive/Rolls/ghost-extended/Others/0017-cq5dam.web.1920.webp
#   inflating: /content/drive/MyDrive/Rolls/ghost-extended/Others/0004-cq5dam.web.1920.webp
#   inflating: /content/drive/MyDrive/Rolls/ghost-extended/classification_log.json
#    creating: /content/drive/MyDrive/Rolls/ghost/
#    creating: /content/drive/MyDrive/Rolls/ghost/Exterior/
#   inflating: /content/drive/MyDrive/Rolls/ghost/Exterior/Car-Roof_0009-cq5dam.web.1920.webp
#   inflating: /content/drive/MyDrive/Rolls/ghost/Exterior/Car-Roof_0014-cq5dam.web.1920.png
#   inflating: /content/drive/MyDrive/Rolls/ghost/Exterior/Car-Roof_0015-cq5dam.web.1920.webp
#   inflating: /content/drive/MyDrive/Rolls/ghost/Exterior/Car-Roof_0016-cq5dam.web.1920.png
#   inflating: /content/drive/MyDrive/Rolls/ghost/Exterior/Car-Roof_0008-cq5dam.web.1920.jpeg
#   inflating: /content/drive/MyDrive/Rolls/ghost/Exterior/Battery(EV-Hybrid)_0002-cq5dam.web.1920.webp
#   inflating: /content/drive/MyDrive/Rolls/ghost/Exterior/Battery(EV-Hybrid)_0001-cq5dam.web.1920.jpeg
#   inflating: /content/drive/MyDrive/Rolls/ghost/Exterior/Car-Roof_0010-cq5dam.web.1920.jpeg
#   inflating: /content/drive/MyDrive/Rolls/ghost/Exterior/Car-Roof_0007-cq5dam.web.1920.webp
#   inflating: /content/drive/MyDrive/Rolls/ghost/Exterior/Car-Roof_0003-cq5dam.web.1920.png
#   inflating: /content/drive/MyDrive/Rolls/ghost/Exterior/Exterior-General_0024-TILE-GSII-DISCOVER-TWIN-16_9.jpg
#   inflating: /content/drive/MyDrive/Rolls/ghost/Exterior/Car-Roof_0004-cq5dam.web.1920.webp
#   inflating: /content/drive/MyDrive/Rolls/ghost/Exterior/Car-Roof_0013-cq5dam.web.1920.webp
#    creating: /content/drive/MyDrive/Rolls/ghost/Interior/
#    creating: /content/drive/MyDrive/Rolls/ghost/Others/
#  extracting: /content/drive/MyDrive/Rolls/ghost/Others/0026-touch-icon-ipad.png
#  extracting: /content/drive/MyDrive/Rolls/ghost/Others/0028-touch-icon-ipad-retina.png
#  extracting: /content/drive/MyDrive/Rolls/ghost/Others/0025-apple-touch-icon-iphone.png
#   inflating: /content/drive/MyDrive/Rolls/ghost/Others/0005-cq5dam.web.1920.webp
#   inflating: /content/drive/MyDrive/Rolls/ghost/Others/0011-cq5dam.web.1920.webp
#   inflating: /content/drive/MyDrive/Rolls/ghost/Others/0032-favicon.png
#   inflating: /content/drive/MyDrive/Rolls/ghost/Others/error_0030-flags.png
#   inflating: /content/drive/MyDrive/Rolls/ghost/Others/0022-original
#   inflating: /content/drive/MyDrive/Rolls/ghost/Others/0012-cq5dam.web.1920.png
#   inflating: /content/drive/MyDrive/Rolls/ghost/Others/0020-original
#  extracting: /content/drive/MyDrive/Rolls/ghost/Others/0027-touch-icon-iphone-retina.png
#   inflating: /content/drive/MyDrive/Rolls/ghost/Others/0006-cq5dam.web.1920.png
#   inflating: /content/drive/MyDrive/Rolls/ghost/Others/0018-original
#   inflating: /content/drive/MyDrive/Rolls/ghost/Others/0019-cq5dam.web.1920.webp
#  extracting: /content/drive/MyDrive/Rolls/ghost/Others/0017-cq5dam.web.1920.webp
#   inflating: /content/drive/MyDrive/Rolls/ghost/Others/0021-cq5dam.web.1920.webp
#   inflating: /content/drive/MyDrive/Rolls/ghost/classification_log.json

# %%
import os
import torch
from transformers import BlipProcessor, BlipForConditionalGeneration
from PIL import Image
import re

def rename_images_by_content(main_folder):
    # First, let's check what's actually in the folder
    print(f"📁 Checking folder: {main_folder}")
    print(f"   Exists: {os.path.exists(main_folder)}")

    if not os.path.exists(main_folder):
        print("❌ Folder doesn't exist!")
        return

    print(f"\n📂 Contents of {main_folder}:")
    for item in os.listdir(main_folder):
        item_path = os.path.join(main_folder, item)
        item_type = "📁 DIR" if os.path.isdir(item_path) else "📄 FILE"
        print(f"   {item_type}: {item}")

    # Load the BLIP model
    device = "cuda" if torch.cuda.is_available() else "cpu"
    print(f"\n🔧 Using device: {device}")
    processor = BlipProcessor.from_pretrained("Salesforce/blip-image-captioning-base")
    model = BlipForConditionalGeneration.from_pretrained("Salesforce/blip-image-captioning-base").to(device)

    total_renamed = 0
    total_skipped = 0

    # Traverse all models in the main folder
    for model_name in os.listdir(main_folder):
        model_path = os.path.join(main_folder, model_name)
        if not os.path.isdir(model_path):
            print(f"⏭️  Skipping {model_name} (not a directory)")
            continue

        print(f"\n📂 Found model folder: {model_name}")
        print(f"   Contents: {os.listdir(model_path)}")

        for section in ["Exterior", "Interior"]:
            section_path = os.path.join(model_path, section)
            if not os.path.exists(section_path):
                print(f"   ⚠️  {section} folder not found")
                continue

            print(f"\n🔍 Processing: {model_name}/{section}")

            # Get all image files
            image_files = [f for f in os.listdir(section_path)
                          if os.path.isfile(os.path.join(section_path, f))
                          and f.lower().endswith((".jpg", ".jpeg", ".png"))]

            print(f"   Found {len(image_files)} images")

            for filename in image_files:
                file_path = os.path.join(section_path, filename)

                try:
                    # Generate caption
                    image = Image.open(file_path).convert("RGB")
                    inputs = processor(images=image, return_tensors="pt").to(device)
                    out = model.generate(**inputs, max_new_tokens=15)
                    caption = processor.decode(out[0], skip_special_tokens=True)

                    # Clean up the caption
                    short_name = caption.lower()
                    short_name = re.sub(r'^\s+', '', short_name)
                    short_name = re.sub(r'[^\w\s-]', '', short_name)
                    short_name = re.sub(r'[-\s]+', '_', short_name)
                    short_name = short_name.strip('_')

                    if len(short_name) > 50:
                        short_name = short_name[:50].rsplit('_', 1)[0]

                    if not short_name:
                        short_name = "image"

                    # Preserve original extension
                    original_ext = os.path.splitext(filename)[1]
                    new_filename = f"{short_name}{original_ext}"
                    new_path = os.path.join(section_path, new_filename)

                    # Skip if already has correct name
                    if file_path == new_path:
                        print(f"   ⏭️  {filename} (already correct)")
                        total_skipped += 1
                        continue

                    # Avoid overwriting
                    base, ext = os.path.splitext(new_filename)
                    counter = 1
                    while os.path.exists(new_path):
                        new_path = os.path.join(section_path, f"{base}_{counter}{ext}")
                        counter += 1

                    # Rename
                    os.rename(file_path, new_path)
                    print(f"   ✅ {filename} → {os.path.basename(new_path)}")
                    total_renamed += 1

                except Exception as e:
                    print(f"   ⚠️  Skipping {filename}: {str(e)}")
                    total_skipped += 1

    print(f"\n🎉 Complete! Renamed: {total_renamed} | Skipped: {total_skipped}")

# Run with debug info
rename_images_by_content("/content/TATA")
# Out:
# 📁 Checking folder: /content/TATA
#    Exists: True
#
# 📂 Contents of /content/TATA:
#    📁 DIR: punch
#    📁 DIR: tigor
#    📁 DIR: tiago
#    📁 DIR: tigor-ev
#    📁 DIR: tiago-ev
#    📁 DIR: puncj-ev
#    📁 DIR: safari
#
# 🔧 Using device: cuda
#
# 📂 Found model folder: punch
#    Contents: ['Interior', 'classification_log.json', 'Others', 'Exterior']
#
# 🔍 Processing: punch/Exterior
#    Found 461 images
#    ✅ Exterior-General_0904-DiamondCutAlloyWheels-28.jpg → the_2020_ford_escape_suv.jpg
#    ✅ Exterior-General_1181-IndiasSafestCar-115.jpg → the_car_with_the_hood_open_and_the_hood_open.jpg
#    ✅ Exterior-General_0917-DiamondCutAlloyWheels-34.jpg → the_front_wheel_of_a_blue_2020_honda_hrx.jpg
#    ✅ Rear-view_0518-supports-ISOFIX-1.jpg → a_teddy_bear_sitting_in_the_back_of_a_car.jpg
#    ✅ Rear-view_0066-CalypsoRed-14-3.jpg → the_rear_view_of_the_new_toyota_c_hr.jpg
#    ✅ Exterior-General_0942-DiamondCutAlloyWheels-47.jpg → the_2020_ford_escape_suv_1.jpg
#    ✅ Exterior-General_0078-Outdoor-72-2.jpg → a_blue_car_driving_down_a_highway_at_night.jpg
#    ✅ Engine-Motor-Bay_1155-IndiasSafestCar-102.jpg → the_car_s_engine_is_shown_in_this_diagram.jpg
#    ✅ Exterior-General_0085-Outdoor-79-2.jpg → a_blue_car_driving_down_a_road_at_night.jpg
#    ✅ Engine-Motor-Bay_0418-IndiasSafestCar-29.jpg → a_car_with_a_blueprinted_image_of_the_engine.jpg
#    ✅ Exterior-General_0503-IndiasSafestCar-114.jpg → the_car_with_the_hood_open_and_the_hood_open_1.jpg
#    ✅ Exterior-General_1175-IndiasSafestCar-112.jpg → the_car_with_the_hood_open_and_the_hood_open_2.jpg
#    ✅ Exterior-General_1172-IndiasSafestCar-111.jpg → the_car_with_the_hood_open.jpg
#    ✅ Exterior-General_0887-DiamondCutAlloyWheels-19.jpg → the_front_wheel_of_a_blue_2020_toyota_ra.jpg
#    ✅ Exterior-General_0118-TropicalMist-31-4.jpg → the_new_tata_suv.jpg
#    ✅ Exterior-General_0046-Outdoor-40-2.jpg → a_blue_car_driving_down_a_road_at_night_1.jpg
#    ✅ Exterior-General_0191-DaytonaGrey-34-6.jpg → the_new_hyundai_urx_suv.jpg
#    ✅ Exterior-General_0264-DiamondCutAlloyWheels-7.jpg → the_front_wheel_of_a_blue_2020_jeep.jpg
#    ✅ Engine-Motor-Bay_1152-IndiasSafestCar-101.jpg → the_car_with_the_engine_in_the_center_of_the_body.jpg
#    ✅ Rear-view_0104-TropicalMist-17-4.jpg → the_rear_view_of_the_new_toyota_c_hr_1.jpg
#    ✅ Exterior-General_0110-TropicalMist-23-4.jpg → the_toyota_rad_suv.jpg
#    ✅ Exterior-General_0914-DiamondCutAlloyWheels-33.jpg → the_2020_ford_escape_suv_2.jpg
#    ✅ Exterior-General_0267-DiamondCutAlloyWheels-10.jpg → the_front_wheel_of_a_blue_2020_jeep_compass.jpg
#    ✅ Exterior-General_0030-Outdoor-24-2.jpg → the_toyota_ur_x_suv_is_shown_in_this_image.jpg
#    ✅ Exterior-General_0287-DiamondCutAlloyWheels-30.jpg → the_front_wheel_of_a_blue_2020_toyota_ra_1.jpg
#    ✅ Exterior-General_0944-DiamondCutAlloyWheels-48.jpg → the_2020_ford_escape_suv_3.jpg
#    ✅ Engine-Motor-Bay_1009-IndiasSafestCar-29.jpg → a_car_with_a_blueprinted_image_of_the_engine_1.jpg
#    ✅ Exterior-General_0310-City-1-4.jpg → the_new_tata_electric_suv.jpg
#    ✅ Engine-Motor-Bay_0519-engine-2.jpg → the_new_vw_engine.jpg
#    ✅ Exterior-General_0183-DaytonaGrey-26-6.jpg → the_new_bmw_x1_suv.jpg
#    ✅ Exterior-General_0908-DiamondCutAlloyWheels-30.jpg → the_2020_ford_escape_suv_4.jpg
#    ✅ Exterior-General_0053-Outdoor-47-2.jpg → a_blue_car_driving_down_a_road_at_night_2.jpg
#    ✅ Exterior-General_0312-City-3-3.jpg → the_new_toyota_e_e_electric_suv.jpg
#    ✅ Engine-Motor-Bay_0989-IndiasSafestCar-19.jpg → a_car_with_a_blueprinted_image_of_the_engine_2.jpg
#    ✅ Exterior-General_0927-DiamondCutAlloyWheels-39.jpg → the_front_wheel_of_a_blue_2020_honda_hrx_1.jpg
#    ✅ Exterior-General_0835-90DegreeDoorOpening-44.jpg → the_2020_ford_escape_suv_5.jpg
#    ✅ Rear-view_0172-DaytonaGrey-15-6.jpg → the_rear_view_of_a_grey_car.jpg
#    ✅ Engine-Motor-Bay_0987-IndiasSafestCar-18.jpg → a_car_with_a_blueprinted_image_of_the_engine_3.jpg
#    ✅ Car-Roof_0598-four-speakers-and-two-tweeters.jpg → the_top_view_of_a_blue_car_with_a_blue_roof.jpg
#    ✅ Exterior-General_0400-IndiasSafestCar-11.jpg → a_car_with_the_hood_open.jpg
#    ✅ Engine-Motor-Bay_1013-IndiasSafestCar-31.jpg → a_car_with_a_blueprinted_image_of_the_engine_4.jpg
#    ✅ Engine-Motor-Bay_0501-IndiasSafestCar-112.jpg → the_car_s_engine_is_shown_in_red_and_blue.jpg
#    ✅ Exterior-General_0935-DiamondCutAlloyWheels-43.jpg → the_front_wheel_of_a_blue_car.jpg
#    ✅ Engine-Motor-Bay_1011-IndiasSafestCar-30.jpg → a_car_with_a_blueprinted_image_of_the_engine_5.jpg
#    ✅ Exterior-General_0928-DiamondCutAlloyWheels-40.jpg → the_2020_ford_escape_suv_6.jpg
#    ✅ Rear-view_0033-TornadoBlue-16-1.jpg → the_rear_view_of_the_new_toyota_c_hr_2.jpg
#    ✅ Car-Roof_0804-90DegreeDoorOpening-29.jpg → a_car_with_a_blue_top_and_a_white_roof.jpg
#    ✅ Engine-Motor-Bay_0415-IndiasSafestCar-26.jpg → a_car_with_a_blueprinted_image_of_the_engine_6.jpg
#    ✅ Exterior-General_0113-TropicalMist-26-4.jpg → the_new_ciro_suv.jpg
#    ✅ Front-view_0155-OrcusWhite-33-4.jpg → the_front_view_of_a_white_toyota_suv.jpg
#    ✅ Exterior-General_0845-90DegreeDoorOpening-49.jpg → the_2020_ford_escape_suv_7.jpg
#    ✅ Exterior-General_0294-DiamondCutAlloyWheels-37.jpg → the_front_wheel_of_a_blue_2020_honda_hrx_2.jpg
#    ✅ Exterior-General_0040-Outdoor-34-2.jpg → the_toyota_ur_x_suv_is_shown_in_this_image_1.jpg
#    ✅ Exterior-General_0933-DiamondCutAlloyWheels-42.jpg → the_front_wheel_of_a_blue_2020_ford_escape.jpg
#    ✅ Exterior-General_0940-DiamondCutAlloyWheels-46.jpg → the_2020_ford_escape_suv_8.jpg
#    ✅ Car-Roof_0820-90DegreeDoorOpening-37.jpg → a_blue_car_with_a_white_roof.jpg
#    ✅ Exterior-General_0883-DiamondCutAlloyWheels-17.jpg → the_front_wheel_of_a_blue_2020_jeep_compass_1.jpg
#    ✅ Exterior-General_0271-DiamondCutAlloyWheels-14.jpg → the_front_wheel_of_a_blue_2020_jeep_compass_2.jpg
#    ✅ Exterior-General_0268-DiamondCutAlloyWheels-11.jpg → the_front_wheel_of_a_blue_2020_jeep_compass_3.jpg
#    ✅ Exterior-General_0027-Outdoor-21-2.jpg → the_toyota_ur_x_suv_is_shown_in_this_image_2.jpg
#    ✅ Exterior-General_0008-Outdoor-2-2.jpg → the_toyota_ur_x_suv_is_shown_on_a_road_near_the.jpg
#    ✅ Exterior-General_1168-IndiasSafestCar-109.jpg → the_car_with_the_hood_open_1.jpg
#    ✅ Exterior-General_0033-Outdoor-27-2.jpg → the_toyota_ur_x_suv_is_shown_on_a_road.jpg
#    ✅ Exterior-General_0854-DiamondCutAlloyWheels-3.jpg → the_new_ford_escape_suv.jpg
#    ✅ Exterior-General_1174-IndiasSafestCar-112.jpg → the_car_with_the_hood_open_2.jpg
#    ✅ Exterior-General_0701-dealership-banner-new.jpg → a_red_car_parked_on_a_cobb_road.jpg
#    ✅ Exterior-General_0866-DiamondCutAlloyWheels-9.jpg → the_new_ford_escape_suv_1.jpg
#    ✅ Exterior-General_0238-90DegreeDoorOpening-37.jpg → the_2020_ford_escape_suv_9.jpg
#    ✅ Car-Roof_0768-90DegreeDoorOpening-11.jpg → a_blue_car_with_a_roof_rack.jpg
#    ✅ Exterior-General_0903-DiamondCutAlloyWheels-27.jpg → the_front_wheel_of_a_blue_2020_toyota_ra_2.jpg
#    ✅ Exterior-General_0247-90DegreeDoorOpening-46.jpg → the_2020_ford_escape_suv_10.jpg
#    ✅ Exterior-General_0924-DiamondCutAlloyWheels-38.jpg → the_2020_ford_escape_suv_11.jpg
#    ✅ Exterior-General_0298-DiamondCutAlloyWheels-41.jpg → the_front_wheel_of_a_blue_2020_honda_hrx_3.jpg
#    ✅ Engine-Motor-Bay_0423-IndiasSafestCar-34.jpg → the_car_s_engine_is_shown_in_this_image.jpg
#    ✅ Engine-Motor-Bay_0993-IndiasSafestCar-21.jpg → a_car_with_a_blueprinted_image_of_the_engine_7.jpg
#    ✅ Rear-view_0695-rear-wiper-and-wash-1.jpg → the_rear_view_of_the_new_renault_c_hr.jpg
#    ✅ Exterior-General_0915-DiamondCutAlloyWheels-33.jpg → the_front_wheel_of_a_blue_2020_honda_hrx_4.jpg
#    ✅ Exterior-General_0282-DiamondCutAlloyWheels-25.jpg → the_front_wheel_of_a_blue_2020_toyota_ra_3.jpg
#    ✅ Exterior-General_0048-Outdoor-42-2.jpg → a_blue_car_driving_down_a_road_at_night_3.jpg
#    ✅ Exterior-General_0149-OrcusWhite-27-4.jpg → the_new_ciro_suv_1.jpg
#    ✅ Engine-Motor-Bay_0404-IndiasSafestCar-15.jpg → a_car_with_a_blueprinted_image_of_the_engine_8.jpg
#    ✅ Engine-Motor-Bay_0496-IndiasSafestCar-107.jpg → the_car_s_engine_is_shown_in_red_and_blue_1.jpg
#    ✅ Engine-Motor-Bay_1036-IndiasSafestCar-43.jpg → a_car_with_the_engine_in_the_middle.jpg
#    ✅ Engine-Motor-Bay_0486-IndiasSafestCar-97.jpg → the_car_s_engine_is_shown_in_red_and_white.jpg
#    ✅ Exterior-General_0916-DiamondCutAlloyWheels-34.jpg → the_2020_ford_escape_suv_12.jpg
#    ✅ Exterior-General_0514-front-fog-lamps-with-cornering-function-new.jpg → a_car_is_parked_on_the_street_in_the_middle_of.jpg
#    ✅ Exterior-General_0735-oxide.jpg → the_new_bmw_x1_suv_1.jpg
#    ✅ Exterior-General_0275-DiamondCutAlloyWheels-18.jpg → the_front_wheel_of_a_blue_2020_toyota_ra_4.jpg
#    ✅ Exterior-General_0257-DiamondCutAlloyWheels-0.jpg → the_new_ford_escape_suv_2.jpg
#    ✅ Exterior-General_0923-DiamondCutAlloyWheels-37.jpg → the_front_wheel_of_a_blue_2020_honda_hrx_5.jpg
#    ✅ Exterior-General_0728-punch-navigation.jpg → the_toyota_hrx_suv.jpg
#    ✅ Exterior-General_0326-City-17-3.jpg → the_new_toyota_cx_5_suv.jpg
#    ✅ Car-Roof_0812-90DegreeDoorOpening-33.jpg → a_blue_car_with_a_white_roof_1.jpg
#    ✅ Engine-Motor-Bay_0424-IndiasSafestCar-35.jpg → the_car_s_engine_is_shown_in_this_image_1.jpg
#    ✅ Engine-Motor-Bay_1169-IndiasSafestCar-109.jpg → the_car_with_the_engine_and_the_front_end_of_the.jpg
#    ✅ Engine-Motor-Bay_0981-IndiasSafestCar-15.jpg → a_car_with_a_blueprinted_image_of_the_engine_9.jpg
#    ✅ Exterior-General_0075-Outdoor-69-2.jpg → a_blue_car_driving_down_a_road_at_night_4.jpg
#    ✅ Exterior-General_0930-DiamondCutAlloyWheels-41.jpg → the_2020_ford_escape_suv_13.jpg
#    ✅ Exterior-General_0273-DiamondCutAlloyWheels-16.jpg → the_front_wheel_of_a_blue_2020_jeep_compass_4.jpg
#    ✅ Exterior-General_1170-IndiasSafestCar-110.jpg → the_car_with_the_hood_open_3.jpg
#    ✅ Engine-Motor-Bay_1007-IndiasSafestCar-28.jpg → a_car_with_a_blueprinted_image_of_the_engine_10.jpg
#    ✅ Exterior-General_0505-IndiasSafestCar-116.jpg → the_car_with_the_hood_open_and_the_hood_open_3.jpg
#    ✅ Rear-view_0175-DaytonaGrey-18-6.jpg → the_rear_view_of_the_2019_toyota_hrx.jpg
#    ✅ Exterior-General_0825-90DegreeDoorOpening-39.jpg → the_2020_ford_escape_suv_14.jpg
#    ✅ Exterior-General_0010-Outdoor-4-2.jpg → the_toyota_ur_x_suv_is_shown_on_a_road_1.jpg
#    ✅ Exterior-General_0851-DiamondCutAlloyWheels-1.jpg → the_new_ford_escape_suv_3.jpg
#    ✅ Exterior-General_0947-DiamondCutAlloyWheels-49.jpg → the_front_wheel_of_a_blue_2020_honda_hrx_6.jpg
#    ✅ Exterior-General_0160-DaytonaGrey-3-6.jpg → the_new_ciro_suv_2.jpg
#    ✅ Exterior-General_0057-Outdoor-51-2.jpg → a_blue_car_driving_down_a_road_at_night_5.jpg
#    ✅ Exterior-General_0292-DiamondCutAlloyWheels-35.jpg → the_front_wheel_of_a_blue_2020_honda_hrx_7.jpg
#    ✅ Exterior-General_0182-DaytonaGrey-25-6.jpg → the_new_bmw_x1_suv_2.jpg
#    ✅ Exterior-General_0091-TropicalMist-4-4.jpg → the_new_ciro_suv_3.jpg
#    ✅ Exterior-General_0083-Outdoor-77-2.jpg → a_blue_car_driving_down_a_road_at_night_6.jpg
#    ✅ Exterior-General_0050-TornadoBlue-33-1.jpg → the_new_toyota_suv.jpg
#    ✅ Exterior-General_0017-punch-navigation.jpg → the_new_ciro_suv_4.jpg
#    ✅ Engine-Motor-Bay_0460-IndiasSafestCar-71.jpg → the_car_s_engine_is_shown_with_the_front_end.jpg
#    ✅ Engine-Motor-Bay_1164-IndiasSafestCar-107.jpg → the_car_with_the_engine_in_the_middle.jpg
#    ✅ Exterior-General_0037-Outdoor-31-2.jpg → the_toyota_ur_x_suv_is_shown_in_this_image_3.jpg
#    ✅ Exterior-General_0742-punch-navigation.jpg → the_new_renault_kad_suv.jpg
#    ✅ Exterior-General_0714-Curvv-pv.jpg → the_new_lex_hybrid_suv.jpg
#    ✅ Exterior-General_0075-CalypsoRed-23-3.jpg → the_toyota_rad_suv_1.jpg
#    ✅ Exterior-General_0870-DiamondCutAlloyWheels-11.jpg → the_new_ford_escape_suv_4.jpg
#    ✅ Exterior-General_0837-90DegreeDoorOpening-45.jpg → the_2020_ford_escape_suv_15.jpg
#    ✅ Exterior-General_0913-DiamondCutAlloyWheels-32.jpg → the_new_2020_ford_escape_suv.jpg
#    ✅ Exterior-General_0022-Outdoor-16-2.jpg → toyota_launches_new_suv_for_the_us_market.jpg
#    ✅ Exterior-General_1191-IndiasSafestCar-120.jpg → the_car_with_the_hood_open_4.jpg
#    ✅ Exterior-General_0314-City-5-4.jpg → the_new_tata_electric_suv_1.jpg
#    ✅ Exterior-General_0703-all-pv-banner.jpg → a_group_of_cars_parked_in_a_parking.jpg
#    ✅ Engine-Motor-Bay_0420-IndiasSafestCar-31.jpg → a_car_with_a_blueprinted_image_of_the_engine_11.jpg
#    ✅ Rear-view_0103-TropicalMist-16-4.jpg → the_rear_view_of_the_new_renault_c_hr_1.jpg
#    ✅ Engine-Motor-Bay_0411-IndiasSafestCar-22.jpg → a_car_with_a_blueprinted_image_of_the_engine_12.jpg
#    ✅ Engine-Motor-Bay_0997-IndiasSafestCar-23.jpg → a_car_with_a_blueprinted_image_of_the_engine_13.jpg
#    ✅ Engine-Motor-Bay_0971-IndiasSafestCar-10.jpg → a_car_engine_with_a_blue_glow_on_it.jpg
#    ✅ Exterior-General_0022-TornadoBlue-5-1.jpg → the_new_ciro_suv_5.jpg
#    ✅ Exterior-General_0945-DiamondCutAlloyWheels-48.jpg → the_front_wheel_of_a_blue_2020_honda_hrx_8.jpg
#    ✅ Exterior-General_0265-DiamondCutAlloyWheels-8.jpg → the_front_wheel_of_a_blue_2020_jeep_compass_5.jpg
#    ✅ Exterior-General_1178-IndiasSafestCar-114.jpg → the_car_with_the_hood_open_5.jpg
#    ✅ Engine-Motor-Bay_0403-IndiasSafestCar-14.jpg → a_car_with_a_blueprinted_image_of_the_engine_14.jpg
#    ✅ Exterior-General_0032-Outdoor-26-2.jpg → the_toyota_ur_x_suv_is_shown_on_a_road_2.jpg
#    ✅ Exterior-General_0939-DiamondCutAlloyWheels-45.jpg → the_front_wheel_of_a_blue_2020_ford_escape_1.jpg
#    ✅ Engine-Motor-Bay_1003-IndiasSafestCar-26.jpg → a_car_with_a_blueprinted_image_of_the_engine_15.jpg
#    ✅ Exterior-General_0076-Outdoor-70-2.jpg → a_blue_car_driving_down_a_road_at_night_7.jpg
#    ✅ Exterior-General_0092-TropicalMist-5-4.jpg → the_new_toyota_rad_suv.jpg
#    ✅ Exterior-General_0036-Outdoor-30-2.jpg → the_toyota_ur_x_suv_is_shown_on_a_road_3.jpg
#    ✅ Exterior-General_0284-DiamondCutAlloyWheels-27.jpg → the_front_wheel_of_a_blue_2020_toyota_ra_5.jpg
#    ✅ Exterior-General_1189-IndiasSafestCar-119.jpg → the_car_with_the_hood_open_6.jpg
#    ✅ Exterior-General_0029-Outdoor-23-2.jpg → the_toyota_ur_x_suv_is_shown_in_this_image_4.jpg
#    ✅ Engine-Motor-Bay_0965-IndiasSafestCar-7.jpg → a_black_and_white_image_of_a_motorcycle.jpg
#    ✅ Engine-Motor-Bay_0490-IndiasSafestCar-101.jpg → the_car_s_engine_is_shown_in_red_and_blue_2.jpg
#    ✅ Exterior-General_0295-DiamondCutAlloyWheels-38.jpg → the_front_wheel_of_a_blue_2020_honda_hrx_9.jpg
#    ✅ Exterior-General_0906-DiamondCutAlloyWheels-29.jpg → the_2020_ford_escape_suv_16.jpg
#    ✅ Exterior-General_0023-Outdoor-17-2.jpg → toyota_launches_new_urus_suv.jpg
#    ✅ Engine-Motor-Bay_0504-IndiasSafestCar-115.jpg → the_car_s_engine_is_shown_in_red_and_blue_3.jpg
#    ✅ Exterior-General_0052-Outdoor-46-2.jpg → a_blue_car_driving_down_a_road_at_night_8.jpg
#    ✅ Exterior-General_0049-Outdoor-43-2.jpg → a_blue_car_driving_down_a_road_at_night_9.jpg
#    ✅ Exterior-General_0028-Outdoor-22-2.jpg → the_toyota_ur_x_suv_is_shown_in_this_image_5.jpg
#    ✅ Exterior-General_0500-IndiasSafestCar-111.jpg → the_car_with_the_hood_open_and_the_hood_open_4.jpg
#    ✅ Exterior-General_1185-IndiasSafestCar-117.jpg → the_car_with_the_hood_open_7.jpg
#    ✅ Exterior-General_0833-90DegreeDoorOpening-43.jpg → the_2020_ford_escape_suv_17.jpg
#    ✅ Exterior-General_0018-Outdoor-12-2.jpg → the_toyota_ur_x_suv_is_shown_in_this_image_6.jpg
#    ✅ Exterior-General_0871-DiamondCutAlloyWheels-11.jpg → the_front_wheel_of_a_blue_2020_jeep_compass_6.jpg
#    ✅ Engine-Motor-Bay_0498-IndiasSafestCar-109.jpg → the_car_s_engine_is_shown_in_red_and_blue_4.jpg
#    ✅ Exterior-General_0192-DaytonaGrey-35-6.jpg → the_new_ciro_suv_6.jpg
#    ✅ Exterior-General_0055-CalypsoRed-3-3.jpg → the_new_ciro_suv_7.jpg
#    ✅ Front-view_0190-DaytonaGrey-33-6.jpg → the_front_view_of_a_grey_2019_toyota_ra.jpg
#    ✅ Engine-Motor-Bay_0508-IndiasSafestCar-119.jpg → the_car_s_engine_is_shown_with_the_red_arrows.jpg
#    ✅ Exterior-General_1179-IndiasSafestCar-114.jpg → the_car_with_the_hood_open_and_the_hood_open_5.jpg
#    ✅ Exterior-General_0019-Outdoor-13-2.jpg → the_toyota_ur_x_suv_is_shown_on_a_road_4.jpg
#    ✅ Exterior-General_0005-DaytonaGrey-0-3.jpg → the_new_toyota_rad_suv_1.jpg
#    ✅ Rear-view_0517-rear-defogger-1.jpg → the_rear_view_of_a_blue_and_white_car.jpg
#    ✅ Exterior-General_0059-CalypsoRed-7-3.jpg → the_toyota_rad_suv_2.jpg
#    ✅ Engine-Motor-Bay_0487-IndiasSafestCar-98.jpg → the_car_s_engine_is_shown_in_red_and_white_1.jpg
#    ✅ Exterior-General_0850-DiamondCutAlloyWheels-1.jpg → the_new_ford_escape_suv_5.jpg
#    ✅ Engine-Motor-Bay_0408-IndiasSafestCar-19.jpg → a_car_with_a_blueprinted_image_of_the_engine_16.jpg
#    ✅ Exterior-General_0025-Outdoor-19-2.jpg → the_toyota_ur_x_suv_is_shown_on_a_road_5.jpg
#    ✅ Exterior-General_0311-City-2-4.jpg → the_new_tata_electric_suv_2.jpg
#    ✅ Exterior-General_0293-DiamondCutAlloyWheels-36.jpg → the_front_wheel_of_a_blue_2020_honda_hrx_10.jpg
#    ✅ Exterior-General_0051-TornadoBlue-34-1.jpg → the_new_toyota_ur_x_suv.jpg
#    ✅ Engine-Motor-Bay_0419-IndiasSafestCar-30.jpg → a_car_with_a_blueprinted_image_of_the_engine_17.jpg
#    ✅ Rear-view_0136-OrcusWhite-14-4.jpg → the_rear_view_of_the_new_hyundai_i_n.jpg
#    ✅ Exterior-General_0276-DiamondCutAlloyWheels-19.jpg → the_front_wheel_of_a_blue_2020_toyota_ra_6.jpg
#    ✅ Engine-Motor-Bay_0509-IndiasSafestCar-120.jpg → the_car_s_engine_is_shown_with_the_red_arrows_1.jpg
#    ✅ Exterior-General_1173-IndiasSafestCar-111.jpg → the_car_with_the_hood_open_and_the_hood_open_6.jpg
#    ✅ Engine-Motor-Bay_0982-IndiasSafestCar-16.jpg → a_car_with_a_blueprinted_image_of_the_engine_18.jpg
#    ✅ Exterior-General_0299-DiamondCutAlloyWheels-42.jpg → the_front_wheel_of_a_blue_2020_honda_hrx_11.jpg
#    ✅ Exterior-General_0841-90DegreeDoorOpening-47.jpg → the_2020_ford_escape_suv_18.jpg
#    ✅ Car-Roof_0822-90DegreeDoorOpening-38.jpg → a_blue_car_with_a_white_roof_2.jpg
#    ✅ Car-Roof_0798-90DegreeDoorOpening-26.jpg → a_blue_car_with_a_roof_rack_1.jpg
#    ✅ Exterior-General_0859-DiamondCutAlloyWheels-5.jpg → the_new_ford_escape_suv_6.jpg
#    ✅ Exterior-General_0885-DiamondCutAlloyWheels-18.jpg → the_front_wheel_of_a_blue_2020_jeep_compass_7.jpg
#    ✅ Engine-Motor-Bay_0458-IndiasSafestCar-69.jpg → the_car_s_engine_is_shown_with_the_front_end_1.jpg
#    ✅ Exterior-General_0074-Outdoor-68-2.jpg → a_blue_car_driving_down_a_road_at_night_10.jpg
#    ✅ Engine-Motor-Bay_0494-IndiasSafestCar-105.jpg → the_car_s_engine_is_shown_in_red_and_blue_5.jpg
#    ✅ Exterior-General_0060-CalypsoRed-8-3.jpg → the_toyota_rad_suv_3.jpg
#    ✅ Exterior-General_0910-DiamondCutAlloyWheels-31.jpg → the_2020_ford_escape_suv_19.jpg
#    ✅ Exterior-General_0858-DiamondCutAlloyWheels-5.jpg → the_new_ford_escape_suv_7.jpg
#    ✅ Exterior-General_0286-DiamondCutAlloyWheels-29.jpg → the_front_wheel_of_a_blue_2020_toyota_hrx.jpg
#    ✅ Exterior-General_1162-IndiasSafestCar-106.jpg → the_car_with_the_hood_open_8.jpg
#    ✅ Front-view_1528-dealership-banner-new.jpg → the_toyota_rad_suv_parked_in_front_of_a_building.jpg
#    ✅ Engine-Motor-Bay_0985-IndiasSafestCar-17.jpg → a_car_with_a_blueprinted_image_of_the_engine_19.jpg
#    ✅ Engine-Motor-Bay_0507-IndiasSafestCar-118.jpg → the_car_s_engine_is_shown_with_the_red_arrows_2.jpg
#    ✅ Exterior-General_0303-DiamondCutAlloyWheels-46.jpg → the_front_wheel_of_a_blue_2020_honda_hrx_12.jpg
#    ✅ Exterior-General_1183-IndiasSafestCar-116.jpg → the_car_with_the_hood_open_9.jpg
#    ✅ Engine-Motor-Bay_0976-IndiasSafestCar-13.jpg → a_car_engine_with_the_hood_up.jpg
#    ✅ Engine-Motor-Bay_0972-IndiasSafestCar-11.jpg → a_car_engine_with_the_hood_open.jpg
#    ✅ Exterior-General_0291-DiamondCutAlloyWheels-34.jpg → the_front_wheel_of_a_blue_2020_honda_hrx_13.jpg
#    ✅ Exterior-General_0290-DiamondCutAlloyWheels-33.jpg → the_front_wheel_of_a_blue_2020_honda_hrx_14.jpg
#    ✅ Exterior-General_0281-DiamondCutAlloyWheels-24.jpg → the_front_wheel_of_a_blue_2020_honda_hrx_15.jpg
#    ✅ Exterior-General_0067-Outdoor-61-2.jpg → a_blue_car_driving_down_a_road_at_night_11.jpg
#    ✅ Engine-Motor-Bay_0422-IndiasSafestCar-33.jpg → the_car_s_engine_is_shown_in_this_image_2.jpg
#    ✅ Exterior-General_0132-OrcusWhite-10-4.jpg → the_new_ciro_suv_8.jpg
#    ✅ Exterior-General_0163-DaytonaGrey-6-6.jpg → the_bmw_x1_suv.jpg
#    ✅ Exterior-General_0899-DiamondCutAlloyWheels-25.jpg → the_front_wheel_of_a_blue_2020_toyota_ra_7.jpg
#    ✅ Exterior-General_0263-DiamondCutAlloyWheels-6.jpg → the_front_wheel_of_a_blue_2020_ford_escape_2.jpg
#    ✅ Exterior-General_0821-90DegreeDoorOpening-37.jpg → a_blue_2020_ford_escape_suv.jpg
#    ✅ Engine-Motor-Bay_0421-IndiasSafestCar-32.jpg → the_car_s_engine_is_shown_in_this_image_3.jpg
#    ✅ Exterior-General_1184-IndiasSafestCar-117.jpg → the_car_with_the_hood_open_10.jpg
#    ✅ Exterior-General_0021-TornadoBlue-4-1.jpg → the_new_ciro_suv_9.jpg
#    ✅ Engine-Motor-Bay_1147-IndiasSafestCar-98.jpg → the_car_s_engine_is_shown_in_this_diagram_1.jpg
#    ✅ Exterior-General_0925-DiamondCutAlloyWheels-38.jpg → the_front_wheel_of_a_blue_2020_honda_hrx_16.jpg
#    ✅ Engine-Motor-Bay_0466-IndiasSafestCar-77.jpg → the_car_s_engine_is_shown_in_red.jpg
#    ✅ Exterior-General_0045-Outdoor-39-2.jpg → a_blue_car_driving_down_a_road_at_night_12.jpg
#    ✅ Engine-Motor-Bay_1167-IndiasSafestCar-108.jpg → the_car_with_the_engine_and_the_front_end_of_the_1.jpg
#    ✅ Exterior-General_0304-DiamondCutAlloyWheels-47.jpg → the_front_wheel_of_a_blue_2020_honda_hrx_17.jpg
#    ✅ Exterior-General_0890-DiamondCutAlloyWheels-21.jpg → the_2020_kia_soul_is_a_compact_suv_with_a_sporty.jpg
#    ✅ Exterior-General_0012-Outdoor-6-2.jpg → the_toyota_ur_x_suv_is_shown_in_this_image_7.jpg
#    ✅ Engine-Motor-Bay_0973-IndiasSafestCar-11.jpg → a_car_engine_with_the_hood_open_1.jpg
#    ✅ Exterior-General_0262-DiamondCutAlloyWheels-5.jpg → the_front_wheel_of_a_blue_2020_ford_escape_3.jpg
#    ✅ Exterior-General_0932-DiamondCutAlloyWheels-42.jpg → the_2020_ford_escape_suv_20.jpg
#    ✅ Exterior-General_0056-Outdoor-50-2.jpg → a_blue_car_driving_down_a_road_at_night_13.jpg
#    ✅ Exterior-General_0946-DiamondCutAlloyWheels-49.jpg → the_2020_ford_escape_suv_21.jpg
#    ✅ Exterior-General_0261-DiamondCutAlloyWheels-4.jpg → the_new_2020_ford_escape_suv_1.jpg
#    ✅ Exterior-General_1187-IndiasSafestCar-118.jpg → the_car_with_the_hood_open_11.jpg
#    ✅ Exterior-General_0125-OrcusWhite-3-4.jpg → the_new_ciro_suv_10.jpg
#    ✅ Rear-view_0100-TropicalMist-13-4.jpg → the_rear_view_of_the_new_toyota_c_hr_3.jpg
#    ✅ Exterior-General_1171-IndiasSafestCar-110.jpg → the_car_with_the_hood_open_and_the_hood_open_7.jpg
#    ✅ Exterior-General_1531-all-pv-banner.jpg → four_different_colored_cars_parked_in_a_row.jpg
#    ✅ Exterior-General_0512-auto-headlamps-4.jpg → a_blue_car_driving_through_a_rain_storm.jpg
#    ✅ Exterior-General_0289-DiamondCutAlloyWheels-32.jpg → the_front_wheel_of_a_blue_2020_honda_hrx_18.jpg
#    ✅ Engine-Motor-Bay_1150-IndiasSafestCar-100.jpg → the_car_with_the_engine_and_the_front_end_cut_off.jpg
#    ✅ Exterior-General_0502-IndiasSafestCar-113.jpg → the_car_with_the_hood_open_and_the_hood_open_8.jpg
#    ✅ Exterior-General_0272-DiamondCutAlloyWheels-15.jpg → the_front_wheel_of_a_blue_2020_jeep_compass_8.jpg
#    ✅ Exterior-General_0278-DiamondCutAlloyWheels-21.jpg → the_front_wheel_of_a_blue_2020_toyota_ra_8.jpg
#    ✅ Engine-Motor-Bay_0412-IndiasSafestCar-23.jpg → a_car_with_a_blueprinted_image_of_the_engine_20.jpg
#    ✅ Exterior-General_0017-Outdoor-11-2.jpg → the_toyota_ur_x_suv_is_shown_in_this_image_8.jpg
#    ✅ Rear-view_0174-DaytonaGrey-17-6.jpg → the_rear_view_of_the_new_toyota_c_hr_4.jpg
#    ✅ Exterior-General_0891-DiamondCutAlloyWheels-21.jpg → the_front_wheel_of_a_blue_2020_toyota_ra_9.jpg
#    ✅ Exterior-General_0120-TropicalMist-33-4.jpg → the_new_tata_suv_1.jpg
#    ✅ Engine-Motor-Bay_0979-IndiasSafestCar-14.jpg → a_car_with_a_blueprinted_image_of_the_engine_21.jpg
#    ✅ Exterior-General_0852-DiamondCutAlloyWheels-2.jpg → the_new_ford_escape_suv_8.jpg
#    ✅ Exterior-General_0114-TropicalMist-27-4.jpg → the_new_ciro_electric_suv.jpg
#    ✅ Exterior-General_1193-IndiasSafestCar-121.jpg → the_car_with_the_hood_open_12.jpg
#    ✅ Exterior-General_0829-90DegreeDoorOpening-41.jpg → a_blue_2020_ford_escape_suv_1.jpg
#    ✅ Exterior-General_0895-DiamondCutAlloyWheels-23.jpg → the_front_wheel_of_a_blue_2020_toyota_ra_10.jpg
#    ✅ Exterior-General_0843-90DegreeDoorOpening-48.jpg → the_2020_ford_escape_suv_22.jpg
#    ✅ Engine-Motor-Bay_1020-IndiasSafestCar-35.jpg → a_car_with_the_engine_in_the_center_of_it.jpg
#    ✅ Exterior-General_0877-DiamondCutAlloyWheels-14.jpg → the_2020_ford_escape_suv_23.jpg
#    ✅ Exterior-General_1529-dealership-banner-new.jpg → a_red_car_parked_on_a_brick_street.jpg
#    ✅ Engine-Motor-Bay_1149-IndiasSafestCar-99.jpg → the_car_s_engine_is_connected_to_the_vehicle_s.jpg
#    ✅ Exterior-General_0162-DaytonaGrey-5-6.jpg → the_new_bmw_x1_suv_3.jpg
#    ✅ Exterior-General_0936-DiamondCutAlloyWheels-44.jpg → the_2020_ford_escape_suv_24.jpg
#    ✅ Exterior-General_0007-Outdoor-1-2.jpg → the_toyota_ur_x_suv_is_shown_in_this_image_9.jpg
#    ✅ Exterior-General_0121-TropicalMist-34-4.jpg → the_new_toyota_ur_x_suv_1.jpg
#    ✅ Engine-Motor-Bay_0406-IndiasSafestCar-17.jpg → a_car_with_a_blueprinted_image_of_the_engine_22.jpg
#    ✅ Exterior-General_1180-IndiasSafestCar-115.jpg → the_car_with_the_hood_open_13.jpg
#    ✅ Exterior-General_0270-DiamondCutAlloyWheels-13.jpg → the_front_wheel_of_a_blue_2020_jeep_compass_9.jpg
#    ✅ Exterior-General_0893-DiamondCutAlloyWheels-22.jpg → the_front_wheel_of_a_blue_2020_toyota_ra_11.jpg
#    ✅ Exterior-General_0596-iss-idle-stop-start-1.jpg → the_new_nissan_e_e_electric_suv.jpg
#    ✅ Rear-view_0068-CalypsoRed-16-3.jpg → the_rear_view_of_the_new_toyota_hrx.jpg
#    ✅ Exterior-General_0300-DiamondCutAlloyWheels-43.jpg → the_front_wheel_of_a_blue_2020_honda_hrx_19.jpg
#    ✅ Engine-Motor-Bay_0491-IndiasSafestCar-102.jpg → the_car_s_engine_is_shown_in_this_diagram_2.jpg
#    ✅ Exterior-General_0905-DiamondCutAlloyWheels-28.jpg → the_front_wheel_of_a_blue_2020_toyota_hrx_1.jpg
#    ✅ Exterior-General_0277-DiamondCutAlloyWheels-20.jpg → the_front_wheel_of_a_blue_2020_toyota_ra_12.jpg
#    ✅ Engine-Motor-Bay_1038-IndiasSafestCar-44.jpg → a_car_with_the_engine_in_the_middle_1.jpg
#    ✅ Car-Roof_0254-stylish-roofrails-new.jpg → a_blue_car_with_a_white_roof_rack.jpg
#    ✅ Exterior-General_0090-TropicalMist-3-4.jpg → the_new_ciro_electric_suv_1.jpg
#    ✅ Exterior-General_0902-DiamondCutAlloyWheels-27.jpg → the_2020_ford_escape_suv_25.jpg
#    ✅ Exterior-General_0931-DiamondCutAlloyWheels-41.jpg → the_front_wheel_of_a_blue_2020_honda_hrx_20.jpg
#    ✅ Exterior-General_0901-DiamondCutAlloyWheels-26.jpg → the_front_wheel_of_a_blue_2020_toyota_ra_13.jpg
#    ✅ Exterior-General_0296-DiamondCutAlloyWheels-39.jpg → the_front_wheel_of_a_blue_2020_honda_hrx_21.jpg
#    ✅ Exterior-General_0280-DiamondCutAlloyWheels-23.jpg → the_front_wheel_of_a_blue_2020_honda_hrx_22.jpg
#    ✅ Engine-Motor-Bay_1015-IndiasSafestCar-32.jpg → a_car_with_a_blueprinted_image_of_the_engine_23.jpg
#    ✅ Exterior-General_0874-DiamondCutAlloyWheels-13.jpg → the_2020_ford_escape_suv_26.jpg
#    ✅ Car-Roof_0810-90DegreeDoorOpening-32.jpg → a_blue_car_with_a_white_top_and_black_roof.jpg
#    ✅ Rear-view_0031-TornadoBlue-14-1.jpg → the_rear_view_of_the_new_toyota_c_hr_5.jpg
#    ✅ Exterior-General_1177-IndiasSafestCar-113.jpg → the_car_with_the_hood_open_and_the_hood_open_9.jpg
#    ✅ Exterior-General_0920-DiamondCutAlloyWheels-36.jpg → the_2020_ford_escape_suv_27.jpg
#    ✅ Rear-view_0067-CalypsoRed-15-3.jpg → the_rear_view_of_the_fiat_ura.jpg
#    ✅ Rear-view_0102-TropicalMist-15-4.jpg → the_rear_view_of_the_new_renault_kad.jpg
#    ✅ Engine-Motor-Bay_0410-IndiasSafestCar-21.jpg → a_car_with_a_blueprinted_image_of_the_engine_24.jpg
#    ✅ Exterior-General_0070-Outdoor-64-2.jpg → a_blue_car_driving_down_a_road_at_night_14.jpg
#    ✅ Exterior-General_0047-Outdoor-41-2.jpg → a_blue_car_driving_down_a_road_at_night_15.jpg
#    ✅ Rear-view_0137-OrcusWhite-15-4.jpg → the_rear_view_of_the_renault_karo.jpg
#    ✅ Exterior-General_0026-Outdoor-20-2.jpg → the_toyota_ur_x_suv_is_shown_on_a_road_6.jpg
#    ✅ Exterior-General_0260-DiamondCutAlloyWheels-3.jpg → the_front_wheel_of_a_blue_2020_jeep_compass_10.jpg
#    ✅ Exterior-General_0889-DiamondCutAlloyWheels-20.jpg → the_front_wheel_of_a_blue_2020_toyota_ra_14.jpg
#    ✅ Engine-Motor-Bay_0005-fortified-cabin-new.jpg → the_car_s_engine_is_shown_in_this_diagram_3.jpg
#    ✅ Car-Roof_0808-90DegreeDoorOpening-31.jpg → a_blue_car_with_a_white_top_and_black_roof_1.jpg
#    ✅ Exterior-General_0081-Outdoor-75-2.jpg → a_blue_car_driving_down_a_road_at_night_16.jpg
#    ✅ Engine-Motor-Bay_0488-IndiasSafestCar-99.jpg → the_car_s_engine_is_shown_in_this_diagram_4.jpg
#    ✅ Engine-Motor-Bay_0401-IndiasSafestCar-12.jpg → a_car_with_a_blueprinted_image_of_the_engine_25.jpg
#    ✅ Exterior-General_0020-Outdoor-14-2.jpg → toyota_s_new_suv_is_a_bit_for_the_city.jpg
#    ✅ Engine-Motor-Bay_0495-IndiasSafestCar-106.jpg → the_car_s_engine_is_shown_in_red_and_blue_6.jpg
#    ✅ Car-Roof_0816-90DegreeDoorOpening-35.jpg → a_blue_car_with_a_white_roof_3.jpg
#    ✅ Exterior-General_0285-DiamondCutAlloyWheels-28.jpg → the_front_wheel_of_a_blue_2020_toyota_hrx_2.jpg
#    ✅ Exterior-General_0079-Outdoor-73-2.jpg → a_blue_car_driving_down_a_road_at_night_17.jpg
#    ✅ Engine-Motor-Bay_0999-IndiasSafestCar-24.jpg → a_car_with_a_blueprinted_image_of_the_engine_26.jpg
#    ✅ Exterior-General_0283-DiamondCutAlloyWheels-26.jpg → the_front_wheel_of_a_blue_2020_honda_hrx_23.jpg
#    ✅ Exterior-General_0050-Outdoor-44-2.jpg → a_blue_car_driving_down_a_road_at_night_18.jpg
#    ✅ Exterior-General_0243-90DegreeDoorOpening-42.jpg → the_2020_ford_escape_suv_28.jpg
#    ✅ Engine-Motor-Bay_0407-IndiasSafestCar-18.jpg → a_car_with_a_blueprinted_image_of_the_engine_27.jpg
#    ✅ Exterior-General_0886-DiamondCutAlloyWheels-19.jpg → the_2020_kia_soul_is_a_compact_suv_with_a_sporty_1.jpg
#    ✅ Exterior-General_0024-TornadoBlue-7-1.jpg → the_toyota_rad_suv_4.jpg
#    ✅ Engine-Motor-Bay_0464-IndiasSafestCar-75.jpg → the_car_s_engine_is_shown_with_the_red_arrows_3.jpg
#    ✅ Exterior-General_0937-DiamondCutAlloyWheels-44.jpg → the_front_wheel_of_a_blue_2020_honda_hrx_24.jpg
#    ✅ Exterior-General_0853-DiamondCutAlloyWheels-2.jpg → the_new_ford_escape_suv_9.jpg
#    ✅ Exterior-General_0054-Outdoor-48-2.jpg → a_blue_car_driving_down_a_road_at_night_19.jpg
#    ✅ Engine-Motor-Bay_0413-IndiasSafestCar-24.jpg → a_car_with_a_blueprinted_image_of_the_engine_28.jpg
#    ✅ Exterior-General_0072-Outdoor-66-2.jpg → a_blue_car_driving_down_a_road_at_night_20.jpg
#    ✅ Exterior-General_0896-DiamondCutAlloyWheels-24.jpg → the_2020_ford_escape_suv_29.jpg
#    ✅ Exterior-General_0013-Outdoor-7-2.jpg → the_toyota_ur_x_suv_is_shown_on_a_road_7.jpg
#    ✅ Exterior-General_0823-90DegreeDoorOpening-38.jpg → a_blue_2020_ford_escape_suv_2.jpg
#    ✅ Exterior-General_0079-CalypsoRed-27-3.jpg → the_new_ciro_electric_suv_2.jpg
#    ✅ Exterior-General_0010-punch-navigation.jpg → the_new_renault_kad_suv_1.jpg
#    ✅ Engine-Motor-Bay_0497-IndiasSafestCar-108.jpg → the_car_s_engine_is_shown_in_red_and_blue_7.jpg
#    ✅ Exterior-General_0734-oxide.jpg → the_new_bmw_x1_suv_4.jpg
#    ✅ Car-Roof_0796-90DegreeDoorOpening-25.jpg → a_blue_car_with_a_roof_rack_2.jpg
#    ✅ Engine-Motor-Bay_0463-IndiasSafestCar-74.jpg → the_car_s_engine_is_shown_with_the_red_arrow.jpg
#    ✅ Exterior-General_0929-DiamondCutAlloyWheels-40.jpg → the_front_wheel_of_a_blue_2020_honda_hrx_25.jpg
#    ✅ Engine-Motor-Bay_1005-IndiasSafestCar-27.jpg → a_car_with_a_blueprinted_image_of_the_engine_29.jpg
#    ✅ Exterior-General_1022-IndiasSafestCar-36.jpg → a_car_with_the_hood_open_1.jpg
#    ✅ Exterior-General_0879-DiamondCutAlloyWheels-15.jpg → the_front_wheel_of_a_blue_2020_jeep_compass_11.jpg
#    ✅ Exterior-General_0039-Outdoor-33-2.jpg → the_toyota_ur_x_suv_is_shown_in_this_image_10.jpg
#    ✅ Engine-Motor-Bay_0506-IndiasSafestCar-117.jpg → the_car_s_engine_is_shown_in_red_and_blue_8.jpg
#    ✅ Exterior-General_0921-DiamondCutAlloyWheels-36.jpg → the_front_wheel_of_a_blue_2020_honda_hrx_26.jpg
#    ✅ Exterior-General_0302-DiamondCutAlloyWheels-45.jpg → the_front_wheel_of_a_blue_2020_honda_hrx_27.jpg
#    ✅ Exterior-General_0058-Outdoor-52-2.jpg → a_blue_car_driving_down_a_road_at_night_21.jpg
#    ✅ Exterior-General_0161-DaytonaGrey-4-6.jpg → the_new_bmw_x1_suv_5.jpg
#    ✅ Exterior-General_0301-DiamondCutAlloyWheels-44.jpg → the_front_wheel_of_a_blue_2020_honda_hrx_28.jpg
#    ✅ Rear-view_0702-book-test-drive-new.jpg → three_people_sitting_in_the_back_of_a_car.jpg
#    ✅ Engine-Motor-Bay_1542-IH_2ndxP3V2pbp7hKjXa92Bx4AJhFkwFPY3PuPdloxjrixI11eueBMEizdMYjo0cXDvLZmwpOwk=s88-c-k-c0x00ffffff-no-rj.jpg → tata_motors.jpg
#    ✅ Exterior-General_0288-DiamondCutAlloyWheels-31.jpg → the_front_wheel_of_a_blue_2020_honda_hrx_29.jpg
#    ✅ Car-Roof_0802-90DegreeDoorOpening-28.jpg → a_car_with_a_blue_top_and_a_white_roof_1.jpg
#    ✅ Engine-Motor-Bay_0467-IndiasSafestCar-78.jpg → the_car_s_engine_is_shown_in_red_1.jpg
#    ✅ Exterior-General_0860-DiamondCutAlloyWheels-6.jpg → the_new_ford_escape_suv_10.jpg
#    ✅ Exterior-General_0089-TropicalMist-2-4.jpg → the_new_toyota_cross_suv.jpg
#    ✅ Exterior-General_0024-Outdoor-18-2.jpg → toyota_s_new_urus_suv_is_a_bit_of_the_future.jpg
#    ✅ Exterior-General_0082-Outdoor-76-2.jpg → a_blue_car_driving_down_a_road_at_night_22.jpg
#    ✅ Engine-Motor-Bay_1160-IndiasSafestCar-105.jpg → the_car_with_the_engine_in_the_trunk.jpg
#    ✅ Exterior-General_0085-CalypsoRed-33-3.jpg → the_new_toyota_suv_1.jpg
#    ✅ Engine-Motor-Bay_1151-IndiasSafestCar-100.jpg → the_car_s_engine_is_shown_in_this_diagram_5.jpg
#    ✅ Exterior-General_0922-DiamondCutAlloyWheels-37.jpg → the_2020_ford_escape_suv_30.jpg
#    ✅ Exterior-General_0307-DiamondCutAlloyWheels-50.jpg → the_front_wheel_of_a_blue_2020_honda_hrx_30.jpg
#    ✅ Engine-Motor-Bay_0465-IndiasSafestCar-76.jpg → the_car_s_engine_is_shown_with_the_red_arrows_4.jpg
#    ✅ Exterior-General_1527-follow-me-home-headlamps-1.jpg → a_couple_of_cars_parked_in_a_driveway.jpg
#    ✅ Exterior-General_0948-DiamondCutAlloyWheels-50.jpg → the_2020_ford_escape_suv_31.jpg
#    ✅ Exterior-General_0897-DiamondCutAlloyWheels-24.jpg → the_front_wheel_of_a_blue_2020_toyota_ra_15.jpg
#    ✅ Engine-Motor-Bay_0402-IndiasSafestCar-13.jpg → a_car_with_a_blueprinted_image_of_the_engine_30.jpg
#    ✅ Exterior-General_0035-Outdoor-29-2.jpg → the_toyota_ur_x_suv_is_shown_on_a_road_8.jpg
#    ✅ Exterior-General_0839-90DegreeDoorOpening-46.jpg → the_2020_ford_escape_suv_32.jpg
#    ✅ Engine-Motor-Bay_1016-IndiasSafestCar-33.jpg → a_car_with_the_engine_in_the_center.jpg
#    ✅ Engine-Motor-Bay_1001-IndiasSafestCar-25.jpg → a_car_with_a_blueprinted_image_of_the_engine_31.jpg
#    ✅ Engine-Motor-Bay_1166-IndiasSafestCar-108.jpg → the_car_with_the_engine_and_the_front_end_cut_off_1.jpg
#    ✅ Exterior-General_0865-DiamondCutAlloyWheels-8.jpg → the_2020_ford_escape_suv_33.jpg
#    ✅ Engine-Motor-Bay_0983-IndiasSafestCar-16.jpg → a_car_with_a_blueprinted_image_of_the_engine_32.jpg
#    ✅ Car-Roof_0800-90DegreeDoorOpening-27.jpg → a_blue_car_with_a_roof_rack_3.jpg
#    ✅ Engine-Motor-Bay_1163-IndiasSafestCar-106.jpg → the_car_with_the_engine_and_the_front_end_cut_off_2.jpg
#    ✅ Exterior-General_0087-CalypsoRed-35-3.jpg → the_new_tata_suv_2.jpg
#    ✅ Exterior-General_0306-DiamondCutAlloyWheels-49.jpg → the_front_wheel_of_a_blue_2020_honda_hrx_31.jpg
#    ✅ Exterior-General_0918-DiamondCutAlloyWheels-35.jpg → the_2020_ford_escape_suv_34.jpg
#    ✅ Exterior-General_0313-City-4-4.jpg → the_new_tata_electric_suv_3.jpg
#    ✅ Exterior-General_0009-Outdoor-3-2.jpg → the_toyota_ur_x_suv_is_shown_on_a_road_9.jpg
#    ✅ Exterior-General_0065-Outdoor-59-2.jpg → a_blue_car_driving_down_a_road_at_night_23.jpg
#    ✅ Exterior-General_0943-DiamondCutAlloyWheels-47.jpg → the_front_wheel_of_a_blue_2020_honda_hrx_32.jpg
#    ✅ Exterior-General_1176-IndiasSafestCar-113.jpg → the_car_with_the_hood_open_14.jpg
#    ✅ Rear-view_0030-TornadoBlue-13-1.jpg → the_rear_view_of_the_new_toyota_c_hr_6.jpg
#    ✅ Exterior-General_0041-Outdoor-35-2.jpg → the_toyota_ur_x_suv_is_shown_in_this_image_11.jpg
#    ✅ Engine-Motor-Bay_1095-IndiasSafestCar-72.jpg → the_car_s_engine_is_shown_in_red_2.jpg
#    ✅ Engine-Motor-Bay_0977-IndiasSafestCar-13.jpg → a_car_with_a_blueprinted_image_of_the_engine_33.jpg
#    ✅ Engine-Motor-Bay_0417-IndiasSafestCar-28.jpg → a_car_with_a_blueprinted_image_of_the_engine_34.jpg
#    ✅ Exterior-General_0073-Outdoor-67-2.jpg → a_blue_car_driving_down_a_road_at_night_24.jpg
#    ✅ Engine-Motor-Bay_0399-IndiasSafestCar-10.jpg → a_car_engine_with_the_hood_open_2.jpg
#    ✅ Engine-Motor-Bay_0974-IndiasSafestCar-12.jpg → a_car_engine_with_a_blue_glow_on_it_1.jpg
#    ✅ Exterior-General_0016-Outdoor-10-2.jpg → the_toyota_ur_x_suv_is_shown_on_a_road_10.jpg
#    ✅ Exterior-General_0127-OrcusWhite-5-4.jpg → the_new_bmw_x1_suv_6.jpg
#    ✅ Exterior-General_0862-DiamondCutAlloyWheels-7.jpg → the_new_ford_escape_suv_11.jpg
#    ✅ Rear-view_0171-DaytonaGrey-14-6.jpg → the_rear_view_of_the_new_toyota_hrx_1.jpg
#    ✅ Exterior-General_0911-DiamondCutAlloyWheels-31.jpg → the_front_wheel_of_a_blue_2020_toyota_ra_16.jpg
#    ✅ Engine-Motor-Bay_0416-IndiasSafestCar-27.jpg → a_car_with_a_blueprinted_image_of_the_engine_35.jpg
#    ✅ Exterior-General_0848-DiamondCutAlloyWheels-0.jpg → the_new_ford_escape_suv_12.jpg
#    ✅ Exterior-General_0741-safari-navigation.jpg → the_new_nissan_terra_suv.jpg
#    ✅ Exterior-General_0258-DiamondCutAlloyWheels-1.jpg → the_new_ford_escape_suv_13.jpg
#    ✅ Exterior-General_0938-DiamondCutAlloyWheels-45.jpg → the_2020_ford_escape_suv_35.jpg
#    ✅ Engine-Motor-Bay_0414-IndiasSafestCar-25.jpg → a_car_with_a_blueprinted_image_of_the_engine_36.jpg
#    ✅ Exterior-General_0344-City-35-3.jpg → the_new_toyota_cx_5_suv_1.jpg
#    ✅ Exterior-General_0152-OrcusWhite-30-4.jpg → the_new_toyota_rad_suv_2.jpg
#    ✅ Rear-view_0135-OrcusWhite-13-4.jpg → the_rear_view_of_the_new_hyundai_cx.jpg
#    ✅ Exterior-General_0819-90DegreeDoorOpening-36.jpg → a_blue_2020_ford_escape_suv_3.jpg
#    ✅ Exterior-General_0020-TornadoBlue-3-1.jpg → the_new_ciro_electric_suv_3.jpg
#    ✅ Exterior-General_0827-90DegreeDoorOpening-40.jpg → a_blue_2020_ford_escape_suv_4.jpg
#    ✅ Exterior-General_0907-DiamondCutAlloyWheels-29.jpg → the_front_wheel_of_a_blue_2020_toyota_ra_17.jpg
#    ✅ Exterior-General_0912-DiamondCutAlloyWheels-32.jpg → the_2020_ford_escape_suv_36.jpg
#    ✅ Car-Roof_0806-90DegreeDoorOpening-30.jpg → a_car_with_a_blue_top_and_a_white_roof_2.jpg
#    ✅ Engine-Motor-Bay_0975-IndiasSafestCar-12.jpg → a_car_with_a_blueprinted_image_of_the_engine_37.jpg
#    ✅ Exterior-General_0941-DiamondCutAlloyWheels-46.jpg → the_front_wheel_of_a_blue_2020_honda_hrx_33.jpg
#    ✅ Exterior-General_0048-TornadoBlue-31-1.jpg → the_new_toyota_e_e_electric_suv_1.jpg
#    ✅ Exterior-General_0297-DiamondCutAlloyWheels-40.jpg → the_front_wheel_of_a_blue_2020_honda_hrx_34.jpg
#    ✅ Engine-Motor-Bay_0409-IndiasSafestCar-20.jpg → a_car_with_a_blueprinted_image_of_the_engine_38.jpg
#    ✅ Exterior-General_0012-navigation-2.jpg → the_mitsubishi_hrx_suv.jpg
#    ✅ Rear-view_0032-TornadoBlue-15-1.jpg → the_rear_view_of_the_new_renault_karo.jpg
#    ✅ Exterior-General_0031-Outdoor-25-2.jpg → the_toyota_ur_x_suv_is_shown_in_this_image_12.jpg
#    ✅ Exterior-General_0949-DiamondCutAlloyWheels-50.jpg → the_front_wheel_of_a_blue_2020_honda_hrx_35.jpg
#    ✅ Exterior-General_0038-Outdoor-32-2.jpg → the_toyota_ur_x_suv_is_shown_on_a_road_11.jpg
#    ✅ Exterior-General_0086-CalypsoRed-34-3.jpg → the_new_toyota_ur_x_suv_2.jpg
#    ✅ Rear-view_0139-OrcusWhite-17-4.jpg → the_rear_view_of_the_new_toyota_c_hr_7.jpg
#    ✅ Exterior-General_0077-Outdoor-71-2.jpg → a_blue_car_driving_down_a_road_at_night_25.jpg
#    ✅ Exterior-General_0011-Outdoor-5-2.jpg → the_toyota_ur_x_suv_is_shown_on_a_road_12.jpg
#    ✅ Exterior-General_0279-DiamondCutAlloyWheels-22.jpg → the_front_wheel_of_a_blue_2020_honda_hrx_36.jpg
#    ✅ Car-Roof_0818-90DegreeDoorOpening-36.jpg → a_blue_car_with_a_white_roof_4.jpg
#    ✅ Engine-Motor-Bay_0995-IndiasSafestCar-22.jpg → a_car_with_a_blueprinted_image_of_the_engine_39.jpg
#    ✅ Exterior-General_1182-IndiasSafestCar-116.jpg → the_car_with_the_hood_open_15.jpg
#    ✅ Exterior-General_0926-DiamondCutAlloyWheels-39.jpg → the_2020_ford_escape_suv_37.jpg
#    ✅ Car-Roof_0814-90DegreeDoorOpening-34.jpg → a_blue_car_with_a_white_roof_5.jpg
#    ✅ Car-Roof_0824-90DegreeDoorOpening-39.jpg → a_blue_car_with_a_white_roof_6.jpg
#    ✅ Rear-view_0173-DaytonaGrey-16-6.jpg → the_rear_view_of_the_new_toyota_hrx_2.jpg
#    ✅ Exterior-General_0021-Outdoor-15-2.jpg → toyota_launches_new_suv_for_the_us_market_1.jpg
#    ✅ Exterior-General_0863-DiamondCutAlloyWheels-7.jpg → the_2020_ford_escape_suv_38.jpg
#    ✅ Engine-Motor-Bay_1153-IndiasSafestCar-101.jpg → the_car_with_the_engine_and_the_front_end_cut_out.jpg
#    ✅ Exterior-General_0847-90DegreeDoorOpening-50.jpg → the_2020_ford_escape_suv_39.jpg
#    ✅ Exterior-General_0055-Outdoor-49-2.jpg → a_blue_car_driving_down_a_road_at_night_26.jpg
#    ✅ Exterior-General_0034-Outdoor-28-2.jpg → the_toyota_ur_x_suv_is_shown_in_this_image_13.jpg
#    ✅ Exterior-General_0269-DiamondCutAlloyWheels-12.jpg → the_front_wheel_of_a_blue_2020_jeep_compass_12.jpg
#    ✅ Exterior-General_0084-Outdoor-78-2.jpg → a_blue_car_driving_down_a_road_at_night_27.jpg
#    ✅ Exterior-General_0043-Outdoor-37-2.jpg → a_blue_toyota_suv_driving_along_the_ocean.jpg
#    ✅ Engine-Motor-Bay_0425-IndiasSafestCar-36.jpg → the_car_s_engine_is_shown_in_this_image_4.jpg
#    ✅ Exterior-General_0111-TropicalMist-24-4.jpg → the_new_toyota_rad_suv_3.jpg
#    ✅ Exterior-General_0274-DiamondCutAlloyWheels-17.jpg → the_front_wheel_of_a_blue_2020_jeep_compass_13.jpg
#    ✅ Engine-Motor-Bay_0405-IndiasSafestCar-16.jpg → a_car_with_a_blueprinted_image_of_the_engine_40.jpg
#    ✅ Exterior-General_0080-Outdoor-74-2.jpg → a_blue_car_driving_down_a_road_at_night_28.jpg
#    ✅ Exterior-General_0093-TropicalMist-6-4.jpg → the_new_toyota_rad_suv_4.jpg
#    ✅ Engine-Motor-Bay_0499-IndiasSafestCar-110.jpg → the_car_s_engine_is_shown_in_red_and_blue_9.jpg
#    ✅ Exterior-General_0884-DiamondCutAlloyWheels-18.jpg → the_2020_ford_escape_suv_40.jpg
#    ✅ Exterior-General_0849-DiamondCutAlloyWheels-0.jpg → the_new_ford_escape_suv_14.jpg
#    ✅ Engine-Motor-Bay_0510-IndiasSafestCar-121.jpg → the_car_s_engine_is_shown_with_the_red_arrows_5.jpg
#    ✅ Rear-view_0170-DaytonaGrey-13-6.jpg → the_rear_view_of_the_new_toyota_c_hr_8.jpg
#    ✅ Exterior-General_0934-DiamondCutAlloyWheels-43.jpg → the_2020_ford_escape_suv_41.jpg
#    ✅ Exterior-General_0882-DiamondCutAlloyWheels-17.jpg → the_2020_ford_escape_suv_42.jpg
#    ✅ Exterior-General_0187-DaytonaGrey-30-6.jpg → the_new_toyota_rad_suv_5.jpg
#    ✅ Engine-Motor-Bay_0461-IndiasSafestCar-72.jpg → the_car_s_engine_is_shown_with_the_red_arrow_1.jpg
#    ✅ Engine-Motor-Bay_0991-IndiasSafestCar-20.jpg → a_car_with_a_blueprinted_image_of_the_engine_41.jpg
#    ✅ Engine-Motor-Bay_1154-IndiasSafestCar-102.jpg → the_car_with_the_engine_in_the_center_of_the_body_1.jpg
#    ✅ Exterior-General_0058-CalypsoRed-6-3.jpg → the_toyota_rad_suv_5.jpg
#    ✅ Rear-view_0138-OrcusWhite-16-4.jpg → the_rear_view_of_the_renault_qx.jpg
#    ✅ Rear-view_0101-TropicalMist-14-4.jpg → the_rear_view_of_the_new_toyota_c_hr_9.jpg
#    ✅ Exterior-General_0831-90DegreeDoorOpening-42.jpg → the_2020_ford_escape_suv_43.jpg
#    ✅ Exterior-General_0040-TornadoBlue-23-1.jpg → the_toyota_rad_suv_6.jpg
#    ✅ Exterior-General_0305-DiamondCutAlloyWheels-48.jpg → the_front_wheel_of_a_blue_2020_honda_hrx_37.jpg
#    ✅ Engine-Motor-Bay_0398-IndiasSafestCar-9.jpg → a_car_engine_with_a_blueprinted_image.jpg
#    ✅ Exterior-General_0071-Outdoor-65-2.jpg → a_blue_car_driving_down_a_road_at_night_29.jpg
#    ✅ Exterior-General_0025-TornadoBlue-8-1.jpg → the_toyota_rad_suv_7.jpg
#    ✅ Exterior-General_0051-Outdoor-45-2.jpg → a_blue_car_driving_down_a_road_at_night_30.jpg
#
# 🔍 Processing: punch/Interior
#    Found 646 images
#    ✅ Dashboard_1254-CruiseControl-30-5.jpg → the_interior_of_a_car_with_a_steering_and.jpg
#    ✅ Dashboard_0216-Infotainment-56.jpg → the_dashboard_of_a_car_with_a_touch_screen.jpg
#    ✅ Dashboard_0208-Infotainment-52.jpg → the_dashboard_of_a_car_with_a_touch_screen_1.jpg
#    ✅ Infotainment-System_0622-WirelessCharger-23-1.jpg → the_interior_of_a_car_with_the_touch_screen.jpg
#    ✅ Infotainment-System_0645-WirelessCharger-46-1.jpg → the_interior_of_a_car_with_the_touch_screen_1.jpg
#    ✅ Infotainment-System_1411-WirelessCharger-34-1.jpg → the_interior_of_a_car_with_a_touch_screen.jpg
#    ✅ Interior-General_0544-CruiseControl-24-5.jpg → the_interior_of_the_tesla_i_pace.jpg
#    ✅ Dashboard_0016-Infotainment-10-1.jpg → the_dashboard_of_a_car_with_a_touch_screen_2.jpg
#    ✅ Infotainment-System_1504-WirelessCharger-81.jpg → the_interior_of_a_car_with_a_touch_screen_1.jpg
#    ✅ Dashboard_0234-Infotainment-65.jpg → the_dashboard_of_a_car_with_a_touch_screen_3.jpg
#    ✅ Dashboard_0283-Infotainment-90.jpg → the_dashboard_of_a_car_with_a_touch_screen_4.jpg
#    ✅ Dashboard_1275-CruiseControl-40-3.jpg → the_interior_of_a_car_with_a_steering_and_1.jpg
#    ✅ Interior-General_1361-WirelessCharger-9-1.jpg → the_interior_of_a_car_with_the_air_vent_and_air.jpg
#    ✅ Dashboard_0254-Infotainment-75.jpg → the_dashboard_of_a_car_with_a_touch_screen_5.jpg
#    ✅ Dashboard_1308-CruiseControl-57-3.jpg → the_interior_of_a_car_with_a_steering_and_2.jpg
#    ✅ Infotainment-System_1374-WirelessCharger-16-1.jpg → the_interior_of_a_car_with_a_touch_screen_2.jpg
#    ✅ Dashboard_0119-Infotainment-8-1.jpg → the_interior_of_a_car_with_a_steering_and_3.jpg
#    ✅ Dashboard_0151-Infotainment-24.jpg → the_interior_of_a_car_with_a_dashboard_and_a.jpg
#    ✅ Dashboard_1249-CruiseControl-27-5.jpg → the_interior_of_a_car_with_a_steering_and_4.jpg
#    ✅ Interior-General_0534-CruiseControl-14-5.jpg → the_interior_of_the_tesla_i_pace_1.jpg
#    ✅ Dashboard_1200-CruiseControl-3-6.jpg → the_interior_of_a_car_with_a_steering_and_5.jpg
#    ✅ Infotainment-System_0643-WirelessCharger-44-1.jpg → the_interior_of_a_car_with_the_touch_screen_2.jpg
#    ✅ Infotainment-System_1373-WirelessCharger-15-1.jpg → the_interior_of_a_car_with_a_touch_screen_3.jpg
#    ✅ Infotainment-System_1425-WirelessCharger-41-1.jpg → the_interior_of_a_car_with_a_touch_screen_4.jpg
#    ✅ Infotainment-System_1396-WirelessCharger-27-1.jpg → the_interior_of_a_car_with_a_touch_screen_5.jpg
#    ✅ Dashboard_0009-Infotainment-3-1.jpg → the_dashboard_of_a_car_with_a_touch_screen_6.jpg
#    ✅ Interior-General_0656-WirelessCharger-57.jpg → the_interior_of_a_car_with_the_air_vent_vent_vent.jpg
#    ✅ Infotainment-System_1500-WirelessCharger-79.jpg → the_interior_of_a_car_with_a_touch_screen_6.jpg
#    ✅ Dashboard_1277-CruiseControl-41-3.jpg → the_interior_of_a_car_with_a_steering_and_6.jpg
#    ✅ Infotainment-System_1488-WirelessCharger-73.jpg → the_interior_of_a_car_with_a_touch_screen_7.jpg
#    ✅ Infotainment-System_1362-WirelessCharger-10-1.jpg → the_interior_of_a_car_with_a_touch_screen_8.jpg
#    ✅ Dashboard_1255-CruiseControl-30-5.jpg → the_interior_of_a_car_with_a_steering_and_7.jpg
#    ✅ Interior-General_0536-CruiseControl-16-5.jpg → the_interior_of_the_tesla_i_pace_2.jpg
#    ✅ Dashboard_1240-CruiseControl-23-5.jpg → the_interior_of_a_car_with_a_steering_and_8.jpg
#    ✅ Dashboard_1327-CruiseControl-66-3.jpg → the_interior_of_a_car_with_a_steering_and_9.jpg
#    ✅ Dashboard_0255-Infotainment-76.jpg → the_dashboard_of_a_car_with_a_touch_screen_7.jpg
#    ✅ Infotainment-System_0612-WirelessCharger-13-1.jpg → the_interior_of_a_car_with_the_touch_screen_3.jpg
#    ✅ Interior-General_1344-WirelessCharger-1-2.jpg → the_interior_of_a_car_with_the_center_console_and.jpg
#    ✅ Dashboard_0148-Infotainment-22-1.jpg → the_dashboard_of_a_car_with_a_touch_screen_8.jpg
#    ✅ Infotainment-System_1390-WirelessCharger-24-1.jpg → the_interior_of_a_car_with_a_touch_screen_9.jpg
#    ✅ Infotainment-System_0644-WirelessCharger-45-1.jpg → the_interior_of_a_car_with_the_touch_screen_4.jpg
#    ✅ Dashboard_0269-Infotainment-83.jpg → the_dashboard_of_a_car_with_a_touch_screen_9.jpg
#    ✅ Dashboard_1326-CruiseControl-66-3.jpg → the_interior_of_a_car_with_a_steering_and_10.jpg
#    ✅ Interior-General_0603-WirelessCharger-4-2.jpg → the_interior_of_a_car_with_the_center_console_and_1.jpg
#    ✅ Infotainment-System_0621-WirelessCharger-22-1.jpg → the_interior_of_a_car_with_the_touch_screen_5.jpg
#    ✅ Interior-General_0524-CruiseControl-4-6.jpg → the_interior_of_the_new_renault_renault.jpg
# ...
#    ✅ Interior-General_0633-MultiMoodLights-19.jpg → the_interior_of_the_new_volvo_concept_12.jpg
#    ✅ Dashboard_1001-DualzoneFATC-50.jpg → the_interior_of_a_car_with_a_view_of_the_dashboard_32.jpg
#    ✅ Interior-General_0479-DualzoneFATC-1.jpg → the_interior_of_the_tesla_i_d_28.jpg
#    ✅ Interior-General_0637-MultiMoodLights-21.jpg → the_interior_of_the_new_bmw_e_pace_53.jpg
#    ✅ Interior-General_0506-DualzoneFATC-28.jpg → the_interior_of_the_tesla_i_d_electric_vehicle_21.jpg
#    ✅ Infotainment-System_0949-DualzoneFATC-24.jpg → the_interior_of_a_car_with_a_view_of_the_driver_s_11.jpg
#    ✅ Front-seats_0039-VentilatedSeats-27-2.jpg → the_interior_of_a_car_with_a_light_blue_seat_cover_40.jpg
#    ✅ Interior-General_0655-MultiMoodLights-30.jpg → the_interior_of_the_new_bmw_e_pace_54.jpg
#    ✅ Dashboard_0989-DualzoneFATC-44.jpg → the_interior_of_a_car_with_a_view_of_the_dashboard_33.jpg
#    ✅ Interior-General_0640-MultiMoodLights-22.jpg → the_interior_of_the_new_bmw_e_pace_55.jpg
#    ✅ Front-seats_0021-VentilatedSeats-9-2.jpg → the_interior_of_a_car_with_white_leather_seats_12.jpg
#    ✅ Front-seats_0169-VentilatedSeats-46-2.jpg → the_interior_of_a_car_with_a_beige_leather_seat_39.jpg
#    ✅ Interior-General_0909-DualzoneFATC-4.jpg → the_interior_of_the_tesla_i_d_29.jpg
#    ✅ Dashboard_1009-air-purifier-new-safari.jpg → the_interior_of_a_car_with_a_dashboard.jpg
#    ✅ Interior-General_0487-DualzoneFATC-9.jpg → the_interior_of_the_tesla_i_d_electric_vehicle_22.jpg
#    ✅ Front-seats_0138-VentilatedSeats-30-2.jpg → the_interior_of_a_car_with_a_light_blue_seat_cover_41.jpg
#    ✅ Front-seats_0051-VentilatedSeats-39-2.jpg → the_interior_of_a_car_with_a_light_blue_seat_cover_42.jpg
#    ✅ Interior-General_0908-DualzoneFATC-4.jpg → the_interior_of_the_tesla_i_d_30.jpg
#    ✅ Interior-General_0921-DualzoneFATC-10.jpg → the_interior_of_the_tesla_i_d_31.jpg
#    ✅ Interior-General_0057-VentilatedSeats-45-2.jpg → the_interior_of_a_car_with_a_blue_and_white_1.jpg
#    ✅ Interior-General_0600-MultiMoodLights-2.jpg → the_interior_of_a_car_with_the_view_of_the_night_1.jpg
#    ✅ Interior-General_0619-MultiMoodLights-12.jpg → the_interior_of_the_new_volvo_concept_13.jpg
#    ✅ Dashboard_0974-DualzoneFATC-37.jpg → the_interior_of_a_car_with_a_view_of_the_dashboard_34.jpg
#    ✅ Front-seats_0128-VentilatedSeats-25-2.jpg → the_interior_of_a_car_with_a_light_blue_seat_cover_43.jpg
#    ✅ Interior-General_0247-MultiMoodLights-3.jpg → the_interior_of_the_new_volkswagen_e_tra_25.jpg
#    ✅ Interior-General_0505-DualzoneFATC-27.jpg → the_interior_of_the_tesla_i_d_electric_vehicle_23.jpg
#    ✅ Interior-General_0952-DualzoneFATC-26.jpg → the_interior_of_a_car_with_a_view_of_the_interior_4.jpg
#    ✅ Front-seats_0036-VentilatedSeats-24-2.jpg → the_interior_of_a_car_with_a_light_blue_seat_cover_44.jpg
#    ✅ Interior-General_0910-DualzoneFATC-5.jpg → the_interior_of_the_tesla_i_d_32.jpg
#    ✅ Interior-General_0896-sunroof-new-safari.jpg → the_interior_of_a_car_with_a_view_of_the_night_sky_6.jpg
#    ✅ Front-seats_0125-VentilatedSeats-24-2.jpg → a_car_with_two_rows_of_seats_in_it.jpg
#    ✅ Interior-General_0695-MultiMoodLights-50.jpg → the_interior_of_the_new_volvo_concept_14.jpg
#    ✅ Interior-General_0945-DualzoneFATC-22.jpg → the_interior_of_the_tesla_i_d_33.jpg
#    ✅ Front-seats_0173-VentilatedSeats-48-2.jpg → the_interior_of_a_car_with_a_beige_leather_seat_40.jpg
#    ✅ Interior-General_0523-DualzoneFATC-45.jpg → the_interior_of_the_tesla_i_d_34.jpg
#    ✅ Interior-General_0943-DualzoneFATC-21.jpg → the_interior_of_the_tesla_i_d_35.jpg
#    ✅ Front-seats_0176-VentilatedSeats-49-2.jpg → the_interior_of_a_car_with_a_beige_leather_seat_41.jpg
#    ✅ Interior-General_0660-MultiMoodLights-32.jpg → the_interior_of_the_new_bmw_e_pace_56.jpg
#    ✅ Interior-General_0941-DualzoneFATC-20.jpg → the_interior_of_the_tesla_i_d_36.jpg
#    ✅ Interior-General_0602-MultiMoodLights-3.jpg → the_interior_of_the_new_bmw_e_pace_57.jpg
#    ✅ Interior-General_0677-MultiMoodLights-41.jpg → the_interior_of_the_new_volvo_concept_15.jpg
#    ✅ Front-seats_0093-VentilatedSeats-8-2.jpg → the_interior_of_a_car_with_beige_leather_seats_13.jpg
#    ✅ Interior-General_0252-MultiMoodLights-8.jpg → the_interior_of_the_new_volkswagen_e_tra_26.jpg
#    ✅ Interior-General_0621-MultiMoodLights-13.jpg → the_interior_of_the_new_volvo_concept_16.jpg
#    ✅ Front-seats_0124-VentilatedSeats-23-2.jpg → the_interior_of_a_car_with_a_light_blue_seat_cover_45.jpg
#    ✅ Interior-General_0262-MultiMoodLights-18.jpg → the_interior_of_the_new_bmw_e_pace_58.jpg
#    ✅ Front-seats_0120-VentilatedSeats-21-2.jpg → the_interior_of_a_car_with_a_light_blue_seat_cover_46.jpg
#    ✅ Interior-General_0617-MultiMoodLights-11.jpg → the_interior_of_the_new_toyota_mira_5.jpg
#    ✅ Front-seats_0171-VentilatedSeats-47-2.jpg → the_interior_of_a_car_with_a_beige_leather_seat_42.jpg
#    ✅ Front-seats_0043-VentilatedSeats-31-2.jpg → the_interior_of_a_car_with_a_light_blue_seat_cover_47.jpg
#    ✅ Interior-General_0907-DualzoneFATC-3.jpg → the_interior_of_the_tesla_i_d_37.jpg
#    ✅ Interior-General_0914-DualzoneFATC-7.jpg → the_interior_of_a_tesla_car_2.jpg
#    ✅ Interior-General_0527-DualzoneFATC-49.jpg → the_interior_of_the_tesla_i_d_38.jpg
#    ✅ Front-seats_0031-VentilatedSeats-19-2.jpg → the_interior_of_a_car_with_a_light_blue_seat_cover_48.jpg
#    ✅ Interior-General_0679-MultiMoodLights-42.jpg → the_interior_of_the_new_bmw_e_pace_59.jpg
#    ✅ Interior-General_0626-MultiMoodLights-15.jpg → the_interior_of_the_new_bmw_e_pace_60.jpg
#    ✅ Front-seats_0108-VentilatedSeats-15-2.jpg → the_interior_of_a_car_with_a_beige_leather_seat_43.jpg
#    ✅ Interior-General_0615-MultiMoodLights-10.jpg → the_interior_of_the_new_volvo_concept_17.jpg
#    ✅ Front-seats_0113-VentilatedSeats-18-2.jpg → the_interior_of_a_car_with_a_beige_leather_seat_44.jpg
#    ✅ Interior-General_0071-benecke-kaliko-oyster-leather-seats.jpg → the_interior_of_a_car_with_a_view_of_the_night_sky_7.jpg
#    ✅ Front-seats_0160-VentilatedSeats-41-2.jpg → the_interior_of_a_car_with_a_beige_leather_seat_45.jpg
#    ✅ Interior-General_0685-MultiMoodLights-45.jpg → the_interior_of_the_new_volvo_concept_18.jpg
#    ✅ Interior-General_0644-MultiMoodLights-24.jpg → the_interior_of_the_new_bmw_e_pace_61.jpg
#    ✅ Interior-General_0684-MultiMoodLights-44.jpg → the_interior_of_the_new_bmw_e_pace_62.jpg
#    ✅ Dashboard_0697-epb-new-safari.jpg → the_interior_of_a_car_with_a_steering_and_a_cup_1.jpg
#    ✅ Interior-General_0598-MultiMoodLights-1.jpg → the_interior_of_the_new_bmw_e_pace_63.jpg
#    ✅ Front-seats_0037-VentilatedSeats-25-2.jpg → the_interior_of_a_car_with_a_light_blue_seat_cover_49.jpg
#    ✅ Front-seats_0164-VentilatedSeats-43-2.jpg → the_interior_of_a_car_with_a_beige_leather_seat_46.jpg
#    ✅ Interior-General_0270-MultiMoodLights-26.jpg → the_interior_of_the_new_bmw_e_pace_64.jpg
#    ✅ Interior-General_0926-DualzoneFATC-13.jpg → the_interior_of_a_car_with_a_view_of_the_interior_5.jpg
#    ✅ Front-seats_0030-VentilatedSeats-18-2.jpg → the_interior_of_a_car_with_a_light_blue_seat_cover_50.jpg
#    ✅ Front-seats_1007-intelligent-spaces-new-safari.jpg → a_toilet_with_a_cell_in_the_seat.jpg
#    ✅ Interior-General_0696-MultiMoodLights-50.jpg → the_interior_of_the_new_bmw_e_pace_65.jpg
#    ✅ Infotainment-System_0959-DualzoneFATC-29.jpg → the_interior_of_a_car_with_a_view_of_the_driver_s_12.jpg
#    ✅ Interior-General_0651-MultiMoodLights-28.jpg → the_interior_of_the_new_bmw_e_pace_66.jpg
#    ✅ Interior-General_0244-MultiMoodLights-0.jpg → the_interior_of_the_new_volkswagen_e_tra_27.jpg
#    ✅ Interior-General_0283-MultiMoodLights-39.jpg → the_interior_of_the_new_bmw_e_pace_67.jpg
#    ✅ Dashboard_0987-DualzoneFATC-43.jpg → the_interior_of_a_car_with_a_view_of_the_dashboard_35.jpg
#    ✅ Dashboard_0973-DualzoneFATC-36.jpg → the_interior_of_a_car_with_a_view_of_the_dashboard_36.jpg
#    ✅ Interior-General_0686-MultiMoodLights-45.jpg → the_interior_of_the_new_bmw_e_pace_68.jpg
#    ✅ Interior-General_0492-DualzoneFATC-14.jpg → the_interior_of_the_tesla_i_d_electric_vehicle_24.jpg
#    ✅ Interior-General_0272-MultiMoodLights-28.jpg → the_interior_of_the_new_bmw_e_pace_69.jpg
#    ✅ Interior-General_0473-android-auto-new-safari.jpg → the_interior_of_the_2020_chevrolet_cam.jpg
#    ✅ Front-seats_0127-VentilatedSeats-25-2.jpg → the_interior_of_a_car_with_a_beige_leather_seat_47.jpg
#    ✅ Front-seats_0061-VentilatedSeats-49-2.jpg → the_interior_of_a_car_with_a_light_blue_seat_cover_51.jpg
#    ✅ Dashboard_0995-DualzoneFATC-47.jpg → the_interior_of_a_car_with_a_view_of_the_dashboard_37.jpg
#    ✅ Interior-General_0915-DualzoneFATC-7.jpg → the_interior_of_the_tesla_i_d_electric_vehicle_25.jpg
#    ✅ Interior-General_0942-DualzoneFATC-21.jpg → the_interior_of_a_car_with_a_view_of_the_interior_6.jpg
#    ✅ Interior-General_0645-MultiMoodLights-25.jpg → the_interior_of_the_new_bmw_e_pace_70.jpg
#    ✅ Interior-General_0906-DualzoneFATC-3.jpg → the_interior_of_the_tesla_i_d_39.jpg
#    ✅ Interior-General_0510-DualzoneFATC-32.jpg → the_interior_of_the_tesla_i_d_40.jpg
#    ✅ Interior-General_0692-MultiMoodLights-48.jpg → the_interior_of_the_new_bmw_e_pace_71.jpg
#    ✅ Dashboard_0474-alexa-new-safari.jpg → a_car_dashboard_with_a_display_showing_the_time.jpg
#    ✅ Interior-General_0257-MultiMoodLights-13.jpg → the_interior_of_the_new_bmw_e_pace_72.jpg
#    ✅ Front-seats_0024-VentilatedSeats-12-2.jpg → the_interior_of_a_car_with_a_light_blue_seat_cover_52.jpg
#    ✅ Front-seats_0087-VentilatedSeats-5-1.jpg → the_interior_of_a_car_with_a_beige_leather_seat_48.jpg
#    ✅ Interior-General_0273-MultiMoodLights-29.jpg → the_interior_of_the_new_bmw_e_pace_73.jpg
#    ✅ Interior-General_0938-DualzoneFATC-19.jpg → the_interior_of_the_tesla_i_d_41.jpg
#    ✅ Front-seats_0027-VentilatedSeats-15-2.jpg → the_interior_of_a_car_with_a_light_blue_seat_cover_53.jpg
#    ✅ Dashboard_0888-cinematic-new-safari.jpg → the_interior_of_a_car_with_a_steering_and_a_touch_2.jpg
#    ✅ Dashboard_0880-multidrive-modes-crop-new.jpg → the_interior_of_a_car_with_a_steering.jpg
#    ✅ Interior-General_0689-MultiMoodLights-47.jpg → the_interior_of_the_new_volvo_concept_19.jpg
#    ✅ Interior-General_0664-MultiMoodLights-34.jpg → the_interior_of_the_new_bmw_e_pace_74.jpg
#    ✅ Front-seats_0094-VentilatedSeats-8-2.jpg → the_interior_of_a_car_with_white_leather_seats_13.jpg
#    ✅ Interior-General_0064-4-way-powered-co-driver-seat-image-rewind.jpg → the_interior_of_the_bmw_e_pace.jpg
#    ✅ Interior-General_0280-MultiMoodLights-36.jpg → the_interior_of_the_new_bmw_e_pace_75.jpg
#    ✅ Interior-General_0264-MultiMoodLights-20.jpg → the_interior_of_the_new_bmw_e_pace_76.jpg
#    ✅ Dashboard_0990-DualzoneFATC-45.jpg → the_interior_of_a_car_with_a_view_of_the_dashboard_38.jpg
#    ✅ Interior-General_0516-DualzoneFATC-38.jpg → the_interior_of_the_new_volvo_electric_vehicle_2.jpg
#    ✅ Interior-General_0285-MultiMoodLights-41.jpg → the_interior_of_the_new_volkswagen_e_tra_28.jpg
#    ✅ Interior-General_0281-MultiMoodLights-37.jpg → the_interior_of_the_new_volkswagen_e_tra_29.jpg
#    ✅ Interior-General_0284-MultiMoodLights-40.jpg → the_interior_of_the_new_bmw_e_pace_77.jpg
#    ✅ Front-seats_0149-VentilatedSeats-36-2.jpg → the_interior_of_a_car_with_beige_leather_seats_14.jpg
#    ✅ Interior-General_0286-MultiMoodLights-42.jpg → the_interior_of_the_new_volkswagen_e_tra_30.jpg
#    ✅ Front-seats_0153-VentilatedSeats-38-2.jpg → the_interior_of_a_car_with_a_beige_leather_seat_49.jpg
#    ✅ Front-seats_0045-VentilatedSeats-33-2.jpg → the_interior_of_a_car_with_a_light_blue_seat_cover_54.jpg
#    ✅ Interior-General_0259-MultiMoodLights-15.jpg → the_interior_of_the_new_volkswagen_e_tra_31.jpg
#    ✅ Front-seats_0063-way-powered-driver-seat-new-safari.jpg → the_interior_of_a_car_with_the_seat_position.jpg
#    ✅ Interior-General_0649-MultiMoodLights-27.jpg → the_interior_of_the_new_bmw_e_pace_78.jpg
#    ✅ Front-seats_0014-VentilatedSeats-2-2.jpg → the_interior_of_a_car_with_a_light_blue_seat_cover_55.jpg
#    ✅ Front-seats_0133-VentilatedSeats-28-2.jpg → the_interior_of_a_car_with_a_beige_leather_seat_50.jpg
#    ✅ Front-seats_0142-VentilatedSeats-32-2.jpg → the_interior_of_a_car_with_a_light_blue_seat_cover_56.jpg
#    ✅ Dashboard_0979-DualzoneFATC-39.jpg → the_interior_of_a_car_with_a_view_of_the_dashboard_39.jpg
#    ✅ Dashboard_0925-DualzoneFATC-12.jpg → the_interior_of_a_car_with_a_view_of_the_dashboard_40.jpg
#    ✅ Interior-General_0493-DualzoneFATC-15.jpg → the_interior_of_the_tesla_i_d_42.jpg
#    ✅ Front-seats_0140-VentilatedSeats-31-2.jpg → the_interior_of_a_car_with_a_light_blue_seat_cover_57.jpg
#    ✅ Infotainment-System_0953-DualzoneFATC-26.jpg → the_interior_of_a_car_with_a_view_of_the_driver_s_13.jpg
#    ✅ Front-seats_0112-VentilatedSeats-17-2.jpg → the_interior_of_a_car_with_a_beige_leather_seat_51.jpg
#    ✅ Infotainment-System_0079-Outdoor-72-2.jpg → the_new_kia_e_trd_concept_is_shown_in_a_1.jpg
#    ✅ Interior-General_0670-MultiMoodLights-37.jpg → the_interior_of_the_new_bmw_e_pace_79.jpg
#    ✅ Dashboard_0009-terrain-response-modes-new-safari.jpg → the_controls_of_a_car_with_a_steering.jpg
#    ✅ Interior-General_0628-MultiMoodLights-16.jpg → the_interior_of_the_new_bmw_e_pace_80.jpg
#    ✅ Interior-General_0607-MultiMoodLights-6.jpg → the_interior_of_the_new_toyota_mira_6.jpg
#    ✅ Interior-General_0496-DualzoneFATC-18.jpg → the_interior_of_the_tesla_i_d_43.jpg
#    ✅ Interior-General_0599-MultiMoodLights-2.jpg → the_interior_of_the_new_toyota_mira_7.jpg
#    ✅ Dashboard_0984-DualzoneFATC-42.jpg → the_interior_of_a_car_with_a_view_of_the_dashboard_41.jpg
#    ✅ Interior-General_0265-MultiMoodLights-21.jpg → the_interior_of_the_new_bmw_e_pace_81.jpg
#    ✅ Interior-General_0618-MultiMoodLights-11.jpg → the_interior_of_the_new_bmw_e_pace_82.jpg
#    ✅ Front-seats_0378-7-air-bags-new-safari-reszd.jpg → the_interior_of_a_car_with_a_beige_leather_seat_52.jpg
#    ✅ Interior-General_0646-MultiMoodLights-25.jpg → the_interior_of_the_new_bmw_e_pace_83.jpg
#    ✅ Front-seats_0053-VentilatedSeats-41-2.jpg → the_interior_of_a_car_with_a_light_blue_seat_cover_58.jpg
#    ✅ Front-seats_0019-VentilatedSeats-7-2.jpg → the_interior_of_a_car_with_a_light_blue_seat_cover_59.jpg
#    ✅ Front-seats_0012-VentilatedSeats-0-2.jpg → the_interior_of_a_car_with_a_light_blue_seat_cover_60.jpg
#    ✅ Interior-General_0930-DualzoneFATC-15.jpg → the_interior_of_a_car_with_a_view_of_the_interior_7.jpg
#    ✅ Front-seats_0029-VentilatedSeats-17-2.jpg → the_interior_of_a_car_with_a_light_blue_seat_cover_61.jpg
#    ✅ Interior-General_0627-MultiMoodLights-16.jpg → the_interior_of_the_new_bmw_e_pace_84.jpg
#    ✅ Front-seats_0095-VentilatedSeats-9-2.jpg → the_interior_of_a_car_with_beige_leather_seats_15.jpg
#    ✅ Interior-General_0528-DualzoneFATC-50.jpg → the_interior_of_the_tesla_i_d_44.jpg
#    ✅ Front-seats_0065-luxorious-3rd-row-seats-new-safari.jpg → the_interior_of_a_car_with_white_leather_seats_14.jpg
#    ✅ Dashboard_0996-DualzoneFATC-48.jpg → the_interior_of_a_car_with_a_view_of_the_dashboard_42.jpg
#    ✅ Interior-General_0500-DualzoneFATC-22.jpg → the_interior_of_the_tesla_i_d_electric_vehicle_26.jpg
#    ✅ Interior-General_0605-MultiMoodLights-5.jpg → the_interior_of_the_new_toyota_mira_8.jpg
#    ✅ Interior-General_0501-DualzoneFATC-23.jpg → the_interior_of_the_tesla_i_d_electric_vehicle_27.jpg
#    ✅ Interior-General_0890-android-auto-new-safari.jpg → the_interior_of_the_2020_chevrolet_camaro.jpg
#    ✅ Interior-General_0519-DualzoneFATC-41.jpg → the_interior_of_the_tesla_i_d_45.jpg
#    ✅ Front-seats_0078-VentilatedSeats-0-2.jpg → the_interior_of_a_car_with_a_beige_leather_seat_53.jpg
#    ✅ Interior-General_0647-MultiMoodLights-26.jpg → the_interior_of_the_new_volvo_concept_20.jpg
#    ✅ Front-seats_0956-DualzoneFATC-28.jpg → the_interior_of_a_car_with_a_view_of_the_rear_and.jpg
#    ✅ Front-seats_0085-VentilatedSeats-4-2.jpg → the_interior_of_a_car_with_a_beige_leather_seat_54.jpg
#    ✅ Front-seats_0161-VentilatedSeats-42-2.jpg → the_interior_of_a_car_with_beige_leather_seats_16.jpg
#    ✅ Interior-General_0504-DualzoneFATC-26.jpg → the_interior_of_the_tesla_i_d_electric_vehicle_28.jpg
#
# 🎉 Complete! Renamed: 4069 | Skipped: 0

# %%
# !rm -rf Hyundai/

# %%
from transformers import CLIPProcessor, CLIPModel
from PIL import Image
import torch, os
from tqdm import tqdm

device = "cuda" if torch.cuda.is_available() else "cpu"
model_name = "openai/clip-vit-base-patch32"
model = CLIPModel.from_pretrained(model_name).to(device)
processor = CLIPProcessor.from_pretrained(model_name)

# Define possible labels
EXTERIOR_TAGS = [
    "front view of car", "rear view of car", "side view of car",
    "top view of car", "car wheel", "car headlight", "taillight", "engine bay", "car roof",
    ""
]
INTERIOR_TAGS = [
    "car dashboard", "steering wheel", "front seats", "rear seats", "gearbox", "infotainment screen",
    "sunroof", "car door interior", "speedometer", "car floor", "boot trunk"
]

MAIN_FOLDER = "/content/drive/MyDrive/Colab Notebooks/tata"
MODEL_FOLDERS = [f for f in os.listdir(MAIN_FOLDER) if os.path.isdir(os.path.join(MAIN_FOLDER, f))]

def rename_images(folder_path, tags):MAIN_FOLDER = "/content/drive/MyDrive/Colab Notebooks/tata1"
OUTPUT_BASE = "TATA1"
model_name = "Salesforce/blip-image-captioning-large"
processor = BlipProcessor.from_pretrained(model_name)
model = BlipForConditionalGeneration.from_pretrained(model_name)

device = "cuda" if torch.cuda.is_available() else "cpu"
model = model.to(device)
print(f"Using device: {device}\n")

print(f" Each model has its own subfolder with Exterior/Interior/Others")
print(f" Check 'classification_log.json' in each folder for details")
print("="*70)
print(f"\nProcessing: {folder_path}")
for img_name in tqdm(os.listdir(folder_path)):
        img_path = os.path.join(folder_path, img_name)
        if not os.path.isfile(img_path):
            continue
        try:
            image = Image.open(img_path).convert("RGB")
            inputs = processor(text=tags, images=image, return_tensors="pt", padding=True).to(device)
            outputs = model(**inputs)
            probs = outputs.logits_per_image.softmax(dim=1)[0]
            best_idx = probs.argmax().item()
            label = tags[best_idx].replace("of car", "").replace("car", "").strip().replace(" ", "-")
            new_name = f"{label}_{img_name}"
            os.rename(img_path, os.path.join(folder_path, new_name))
        except Exception as e:
            print(f"Error processing {img_name}: {e}")

for model_folder in MODEL_FOLDERS:
    print(f"\n===== MODEL: {model_folder} =====")
    exterior_path = os.path.join(MAIN_FOLDER, model_folder, "Exterior")
    interior_path = os.path.join(MAIN_FOLDER, model_folder, "Interior")

    if os.path.exists(exterior_path):
        rename_images(exterior_path, EXTERIOR_TAGS)

    if os.path.exists(interior_path):
        rename_images(interior_path, INTERIOR_TAGS)

print("\n✅ Renaming complete for all model folders.")
# Out:
# preprocessor_config.json:   0%|          | 0.00/445 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/527 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/1.88G [00:00<?, ?B/s]
# Using device: cuda
#
# ======================================================================
# BATCH CAR IMAGE CLASSIFIER
# ======================================================================
# Main folder: /content/drive/MyDrive/Colab Notebooks/tata1
# Output base: TATA1
#
# Found 7 model folders to process:
#
#   1. nixon-ev
#   2. harrier
#   3. nixon
#   4. Harrier
#   5. curvv
#   6. curv-ev
#   7. altroz
#
# ======================================================================
#
# [1/7] Processing: nixon-ev
# ----------------------------------------------------------------------
#   Found 601 valid images
#   Classifying:  18%|█▊        | 110/601 [00:48<03:02,  2.69it/s]The channel dimension is ambiguous. Got image shape (1, 1, 3). Assuming channels are the first dimension. Use the [input_data_format](https://huggingface.co/docs/transformers/main/internal/image_processing_utils#transformers.image_transforms.rescale.input_data_format) parameter to assign the channel dimension.
#   Error processing 0116-ga-audiences: mean must have 1 elements if it is an iterable, got 3
#   Classifying:  19%|█▊        | 112/601 [00:48<02:16,  3.58it/s]The channel dimension is ambiguous. Got image shape (1, 1, 3). Assuming channels are the first dimension. Use the [input_data_format](https://huggingface.co/docs/transformers/main/internal/image_processing_utils#transformers.image_transforms.rescale.input_data_format) parameter to assign the channel dimension.
# The channel dimension is ambiguous. Got image shape (1, 1, 3). Assuming channels are the first dimension. Use the [input_data_format](https://huggingface.co/docs/transformers/main/internal/image_processing_utils#transformers.image_transforms.rescale.input_data_format) parameter to assign the channel dimension.
# The channel dimension is ambiguous. Got image shape (1, 1, 3). Assuming channels are the first dimension. Use the [input_data_format](https://huggingface.co/docs/transformers/main/internal/image_processing_utils#transformers.image_transforms.rescale.input_data_format) parameter to assign the channel dimension.
#   Error processing 0119-ga-audiences: mean must have 1 elements if it is an iterable, got 3
#
#   Error processing 0115-ibs-dpid=411&dpuuid=aQMpCAAAADbHhAN-: mean must have 1 elements if it is an iterable, got 3
#
#   Error processing 0124-dc_pre=CKXV-sjHy5ADFbCPYwYd694MsA;src=15107116;type=nexon0;cat=tml_n0;ord=4260938852489;npa=0;auiddc=-;uaa=x86;uab=64;uafvl=HeadlessChrome-3B141.0.7390.37-7CNot-253FA_Brand-3B8.0.0.0-7CChromium-3B141.0.7390.37;uamb=0;uam: mean must have 1 elements if it is an iterable, got 3
#   Classifying:  19%|█▉        | 116/601 [00:48<01:19,  6.14it/s]The channel dimension is ambiguous. Got image shape (1, 1, 3). Assuming channels are the first dimension. Use the [input_data_format](https://huggingface.co/docs/transformers/main/internal/image_processing_utils#transformers.image_transforms.rescale.input_data_format) parameter to assign the channel dimension.
#   Error processing 0121-registration: mean must have 1 elements if it is an iterable, got 3
#   Results:
#     Exterior: 404 images
#     Interior: 69 images
#     Others:   128 images
#     Total:    601 images
#
# [2/7] Processing: harrier
# ----------------------------------------------------------------------
#   Found 1239 valid images
#   Classifying:  96%|█████████▌| 1192/1239 [07:53<00:17,  2.65it/s]The channel dimension is ambiguous. Got image shape (1, 1, 3). Assuming channels are the first dimension. Use the [input_data_format](https://huggingface.co/docs/transformers/main/internal/image_processing_utils#transformers.image_transforms.rescale.input_data_format) parameter to assign the channel dimension.
#   Error processing 0969-ibs-dpid=411&dpuuid=aQMpRQAAAGZ8mwN8: mean must have 1 elements if it is an iterable, got 3
#   Classifying:  99%|█████████▊| 1222/1239 [08:04<00:07,  2.19it/s]The channel dimension is ambiguous. Got image shape (1, 1, 3). Assuming channels are the first dimension. Use the [input_data_format](https://huggingface.co/docs/transformers/main/internal/image_processing_utils#transformers.image_transforms.rescale.input_data_format) parameter to assign the channel dimension.
#   Error processing 0973-ga-audiences: mean must have 1 elements if it is an iterable, got 3
#   Classifying:  99%|█████████▉| 1228/1239 [08:06<00:03,  3.45it/s]The channel dimension is ambiguous. Got image shape (1, 1, 3). Assuming channels are the first dimension. Use the [input_data_format](https://huggingface.co/docs/transformers/main/internal/image_processing_utils#transformers.image_transforms.rescale.input_data_format) parameter to assign the channel dimension.
#   Classifying:  99%|█████████▉| 1230/1239 [08:06<00:01,  4.85it/s]
#   Error processing 0975-registration: mean must have 1 elements if it is an iterable, got 3
#   Classifying:  99%|█████████▉| 1232/1239 [08:07<00:01,  4.06it/s]The channel dimension is ambiguous. Got image shape (1, 1, 3). Assuming channels are the first dimension. Use the [input_data_format](https://huggingface.co/docs/transformers/main/internal/image_processing_utils#transformers.image_transforms.rescale.input_data_format) parameter to assign the channel dimension.
# The channel dimension is ambiguous. Got image shape (1, 1, 3). Assuming channels are the first dimension. Use the [input_data_format](https://huggingface.co/docs/transformers/main/internal/image_processing_utils#transformers.image_transforms.rescale.input_data_format) parameter to assign the channel dimension.
#   Error processing 0978-c.gif: mean must have 1 elements if it is an iterable, got 3
#
#   Error processing 0985-NRJS-1c1fad81c961ed3a045: image file is truncated (0 bytes not processed)
#
#   Error processing 0979-NRJS-1c1fad81c961ed3a045: image file is truncated (0 bytes not processed)
#
#   Error processing 0983-NRJS-1c1fad81c961ed3a045: image file is truncated (0 bytes not processed)
#
#   Error processing 0982-NRJS-1c1fad81c961ed3a045: image file is truncated (0 bytes not processed)
#
#   Error processing 0986-NRJS-1c1fad81c961ed3a045: image file is truncated (0 bytes not processed)
#
#   Error processing 0976-c.gif: mean must have 1 elements if it is an iterable, got 3
#
#   Results:
#     Exterior: 597 images
#     Interior: 520 images
#     Others:   122 images
#     Total:    1239 images
#
# [3/7] Processing: nixon
# ----------------------------------------------------------------------
#   Found 903 valid images
#   Classifying:  95%|█████████▌| 859/903 [05:40<00:22,  1.93it/s]The channel dimension is ambiguous. Got image shape (1, 1, 3). Assuming channels are the first dimension. Use the [input_data_format](https://huggingface.co/docs/transformers/main/internal/image_processing_utils#transformers.image_transforms.rescale.input_data_format) parameter to assign the channel dimension.
#   Error processing 0798-ibs-dpid=411&dpuuid=aQMo0QAAAEx9qgOn: mean must have 1 elements if it is an iterable, got 3
#   Classifying:  99%|█████████▉| 893/903 [05:54<00:04,  2.45it/s]The channel dimension is ambiguous. Got image shape (1, 1, 3). Assuming channels are the first dimension. Use the [input_data_format](https://huggingface.co/docs/transformers/main/internal/image_processing_utils#transformers.image_transforms.rescale.input_data_format) parameter to assign the channel dimension.
# The channel dimension is ambiguous. Got image shape (1, 1, 3). Assuming channels are the first dimension. Use the [input_data_format](https://huggingface.co/docs/transformers/main/internal/image_processing_utils#transformers.image_transforms.rescale.input_data_format) parameter to assign the channel dimension.
#   Error processing 0804-ga-audiences: mean must have 1 elements if it is an iterable, got 3
#
#   Error processing 0805-c.gif: mean must have 1 elements if it is an iterable, got 3
#   Classifying:  99%|█████████▉| 896/903 [05:54<00:01,  4.12it/s]The channel dimension is ambiguous. Got image shape (1, 1, 3). Assuming channels are the first dimension. Use the [input_data_format](https://huggingface.co/docs/transformers/main/internal/image_processing_utils#transformers.image_transforms.rescale.input_data_format) parameter to assign the channel dimension.
#   Error processing 0808-c.gif: mean must have 1 elements if it is an iterable, got 3
#   Classifying: 100%|█████████▉| 900/903 [05:55<00:00,  4.57it/s]The channel dimension is ambiguous. Got image shape (1, 1, 3). Assuming channels are the first dimension. Use the [input_data_format](https://huggingface.co/docs/transformers/main/internal/image_processing_utils#transformers.image_transforms.rescale.input_data_format) parameter to assign the channel dimension.
#   Error processing 0803-registration: mean must have 1 elements if it is an iterable, got 3
#   Classifying: 100%|█████████▉| 902/903 [05:55<00:00,  5.08it/s]The channel dimension is ambiguous. Got image shape (1, 1, 3). Assuming channels are the first dimension. Use the [input_data_format](https://huggingface.co/docs/transformers/main/internal/image_processing_utils#transformers.image_transforms.rescale.input_data_format) parameter to assign the channel dimension.
#   Error processing 0807-c.gif: mean must have 1 elements if it is an iterable, got 3
#
#   Results:
#     Exterior: 700 images
#     Interior: 21 images
#     Others:   182 images
#     Total:    903 images
#
# [4/7] Processing: Harrier
# ----------------------------------------------------------------------
#   Found 1590 valid images
#   Classifying:  39%|███▊      | 615/1590 [03:47<05:18,  3.06it/s]The channel dimension is ambiguous. Got image shape (1, 1, 3). Assuming channels are the first dimension. Use the [input_data_format](https://huggingface.co/docs/transformers/main/internal/image_processing_utils#transformers.image_transforms.rescale.input_data_format) parameter to assign the channel dimension.
#   Error processing 0621-ibs-dpid=411&dpuuid=aQMppQAAAECl_wOi: mean must have 1 elements if it is an iterable, got 3
#   Classifying:  39%|███▉      | 617/1590 [03:47<04:03,  3.99it/s]The channel dimension is ambiguous. Got image shape (1, 1, 3). Assuming channels are the first dimension. Use the [input_data_format](https://huggingface.co/docs/transformers/main/internal/image_processing_utils#transformers.image_transforms.rescale.input_data_format) parameter to assign the channel dimension.
# The channel dimension is ambiguous. Got image shape (1, 1, 3). Assuming channels are the first dimension. Use the [input_data_format](https://huggingface.co/docs/transformers/main/internal/image_processing_utils#transformers.image_transforms.rescale.input_data_format) parameter to assign the channel dimension.
#   Error processing 0622-ga-audiences: mean must have 1 elements if it is an iterable, got 3
#
#   Error processing 0626-ga-audiences: mean must have 1 elements if it is an iterable, got 3
#   Classifying:  39%|███▉      | 621/1590 [03:48<03:15,  4.97it/s]The channel dimension is ambiguous. Got image shape (1, 1, 3). Assuming channels are the first dimension. Use the [input_data_format](https://huggingface.co/docs/transformers/main/internal/image_processing_utils#transformers.image_transforms.rescale.input_data_format) parameter to assign the channel dimension.
#   Error processing 0630-registration: mean must have 1 elements if it is an iterable, got 3
#
#   Error processing 0638-NRJS-0b059e78cb8dcdc244e: image file is truncated (0 bytes not processed)
#
#   Error processing 0639-blobs: image file is truncated (0 bytes not processed)
#
#   Error processing 0637-NRJS-0b059e78cb8dcdc244e: image file is truncated (0 bytes not processed)
#   Results:
#     Exterior: 1348 images
#     Interior: 45 images
#     Others:   197 images
#     Total:    1590 images
#
# [5/7] Processing: curvv
# ----------------------------------------------------------------------
#   Found 547 valid images
#   Classifying:  95%|█████████▍| 518/547 [03:22<00:14,  2.05it/s]The channel dimension is ambiguous. Got image shape (1, 1, 3). Assuming channels are the first dimension. Use the [input_data_format](https://huggingface.co/docs/transformers/main/internal/image_processing_utils#transformers.image_transforms.rescale.input_data_format) parameter to assign the channel dimension.
#   Error processing 0429-ibs-dpid=411&dpuuid=aQMXTgAAAGcu4QM4: mean must have 1 elements if it is an iterable, got 3
#   Classifying:  95%|█████████▌| 522/547 [03:23<00:08,  3.00it/s]The channel dimension is ambiguous. Got image shape (1, 1, 3). Assuming channels are the first dimension. Use the [input_data_format](https://huggingface.co/docs/transformers/main/internal/image_processing_utils#transformers.image_transforms.rescale.input_data_format) parameter to assign the channel dimension.
#   Classifying:  96%|█████████▌| 524/547 [03:23<00:05,  4.24it/s]
#   Error processing 0435-ga-audiences: mean must have 1 elements if it is an iterable, got 3
# The channel dimension is ambiguous. Got image shape (1, 1, 3). Assuming channels are the first dimension. Use the [input_data_format](https://huggingface.co/docs/transformers/main/internal/image_processing_utils#transformers.image_transforms.rescale.input_data_format) parameter to assign the channel dimension.
# The channel dimension is ambiguous. Got image shape (1, 1, 3). Assuming channels are the first dimension. Use the [input_data_format](https://huggingface.co/docs/transformers/main/internal/image_processing_utils#transformers.image_transforms.rescale.input_data_format) parameter to assign the channel dimension.
#   Error processing 0439-registration: mean must have 1 elements if it is an iterable, got 3
#
#   Error processing 0445-dc_pre=CNDOo9a2y5ADFSmSrAIds4sc2g;src=15104457;type=tatacpv;cat=tml_c0;ord=9720104701609;npa=0;auiddc=-;uaa=x86;uab=64;uafvl=HeadlessChrome-3B141.0.7390.37-7CNot-253FA_Brand-3B8.0.0.0-7CChromium-3B141.0.7390.37;uamb=0;ua: mean must have 1 elements if it is an iterable, got 3
#   Classifying:  97%|█████████▋| 528/547 [03:24<00:03,  5.09it/s]The channel dimension is ambiguous. Got image shape (1, 1, 3). Assuming channels are the first dimension. Use the [input_data_format](https://huggingface.co/docs/transformers/main/internal/image_processing_utils#transformers.image_transforms.rescale.input_data_format) parameter to assign the channel dimension.
#   Error processing 0444-dc_pre=CP_hjNa2y5ADFXGrrAIdm60YzA;src=8951773;type=tatac0;cat=tml_c0;ord=9606117465608;npa=0;auiddc=-;uaa=x86;uab=64;uafvl=HeadlessChrome-3B141.0.7390.37-7CNot-253FA_Brand-3B8.0.0.0-7CChromium-3B141.0.7390.37;uamb=0;uam=: mean must have 1 elements if it is an iterable, got 3
#   Classifying:  99%|█████████▉| 541/547 [03:28<00:01,  3.03it/s]The channel dimension is ambiguous. Got image shape (1, 1, 3). Assuming channels are the first dimension. Use the [input_data_format](https://huggingface.co/docs/transformers/main/internal/image_processing_utils#transformers.image_transforms.rescale.input_data_format) parameter to assign the channel dimension.
# The channel dimension is ambiguous. Got image shape (1, 1, 3). Assuming channels are the first dimension. Use the [input_data_format](https://huggingface.co/docs/transformers/main/internal/image_processing_utils#transformers.image_transforms.rescale.input_data_format) parameter to assign the channel dimension.
#   Error processing 0446-c.gif: mean must have 1 elements if it is an iterable, got 3
#
#   Error processing 0465-NRJS-1c1fad81c961ed3a045: image file is truncated (0 bytes not processed)
#
#   Error processing 0458-c.gif: mean must have 1 elements if it is an iterable, got 3
#
#   Error processing 0462-NRJS-1c1fad81c961ed3a045: image file is truncated (0 bytes not processed)
#
#   Error processing 0466-NRJS-1c1fad81c961ed3a045: image file is truncated (0 bytes not processed)
#   Results:
#     Exterior: 449 images
#     Interior: 11 images
#     Others:   87 images
#     Total:    547 images
#
# [6/7] Processing: curv-ev
# ----------------------------------------------------------------------
#   Found 659 valid images
#   Classifying:  15%|█▌        | 101/659 [00:42<03:17,  2.82it/s]The channel dimension is ambiguous. Got image shape (1, 1, 3). Assuming channels are the first dimension. Use the [input_data_format](https://huggingface.co/docs/transformers/main/internal/image_processing_utils#transformers.image_transforms.rescale.input_data_format) parameter to assign the channel dimension.
#   Error processing 0110-ibs-dpid=411&dpuuid=aQMXmAAAAJ8VhwM5: mean must have 1 elements if it is an iterable, got 3
#   Classifying:  16%|█▌        | 103/659 [00:42<02:19,  4.00it/s]The channel dimension is ambiguous. Got image shape (1, 1, 3). Assuming channels are the first dimension. Use the [input_data_format](https://huggingface.co/docs/transformers/main/internal/image_processing_utils#transformers.image_transforms.rescale.input_data_format) parameter to assign the channel dimension.
# The channel dimension is ambiguous. Got image shape (1, 1, 3). Assuming channels are the first dimension. Use the [input_data_format](https://huggingface.co/docs/transformers/main/internal/image_processing_utils#transformers.image_transforms.rescale.input_data_format) parameter to assign the channel dimension.
#   Error processing 0111-ga-audiences: mean must have 1 elements if it is an iterable, got 3
#
#   Error processing 0114-ga-audiences: mean must have 1 elements if it is an iterable, got 3
#   Classifying:  16%|█▋        | 108/659 [00:43<02:08,  4.29it/s]The channel dimension is ambiguous. Got image shape (1, 1, 3). Assuming channels are the first dimension. Use the [input_data_format](https://huggingface.co/docs/transformers/main/internal/image_processing_utils#transformers.image_transforms.rescale.input_data_format) parameter to assign the channel dimension.
#   Error processing 0116-registration: mean must have 1 elements if it is an iterable, got 3
#   Classifying:  17%|█▋        | 110/659 [00:44<02:02,  4.48it/s]The channel dimension is ambiguous. Got image shape (1, 1, 3). Assuming channels are the first dimension. Use the [input_data_format](https://huggingface.co/docs/transformers/main/internal/image_processing_utils#transformers.image_transforms.rescale.input_data_format) parameter to assign the channel dimension.
#   Error processing 0123-dc_pre=CMqjvfi2y5ADFeSfZgIdjIszHw;src=15068381;type=curvvev0;cat=tml_c004;ord=7040661486493;npa=0;auiddc=-;uaa=x86;uab=64;uafvl=HeadlessChrome-3B141.0.7390.37-7CNot-253FA_Brand-3B8.0.0.0-7CChromium-3B141.0.7390.37;uamb=0: mean must have 1 elements if it is an iterable, got 3
#
#   Error processing 0148-blobs: image file is truncated (0 bytes not processed)
#
#   Error processing 0142-blobs: image file is truncated (0 bytes not processed)
#   Classifying:  17%|█▋        | 114/659 [00:44<01:25,  6.41it/s]
#   Error processing 0146-blobs: image file is truncated (0 bytes not processed)
#   Classifying:  18%|█▊        | 116/659 [00:44<01:30,  5.99it/s]
#   Error processing 0145-NRJS-0b059e78cb8dcdc244e: image file is truncated (0 bytes not processed)
#   Classifying:  18%|█▊        | 118/659 [00:45<01:33,  5.82it/s]
#   Error processing 0143-NRJS-0b059e78cb8dcdc244e: image file is truncated (0 bytes not processed)
#   Results:
#     Exterior: 430 images
#     Interior: 76 images
#     Others:   153 images
#     Total:    659 images
#
# [7/7] Processing: altroz
# ----------------------------------------------------------------------
#   Found 1170 valid images
#   Classifying:  92%|█████████▏| 1077/1170 [07:01<00:33,  2.82it/s]The channel dimension is ambiguous. Got image shape (1, 1, 3). Assuming channels are the first dimension. Use the [input_data_format](https://huggingface.co/docs/transformers/main/internal/image_processing_utils#transformers.image_transforms.rescale.input_data_format) parameter to assign the channel dimension.
#   Error processing 1061-ibs-dpid=411&dpuuid=aQMX2wAAAFjJKgOn: mean must have 1 elements if it is an iterable, got 3
#
#   Error processing 1069-blobs: image file is truncated (0 bytes not processed)
#
#   Error processing 1070-NRJS-1c1fad81c961ed3a045: image file is truncated (0 bytes not processed)
#   Classifying:  92%|█████████▏| 1082/1170 [07:02<00:18,  4.82it/s]The channel dimension is ambiguous. Got image shape (1, 1, 3). Assuming channels are the first dimension. Use the [input_data_format](https://huggingface.co/docs/transformers/main/internal/image_processing_utils#transformers.image_transforms.rescale.input_data_format) parameter to assign the channel dimension.
#   Error processing 1062-ga-audiences: mean must have 1 elements if it is an iterable, got 3
#   Classifying:  93%|█████████▎| 1084/1170 [07:02<00:16,  5.27it/s]The channel dimension is ambiguous. Got image shape (1, 1, 3). Assuming channels are the first dimension. Use the [input_data_format](https://huggingface.co/docs/transformers/main/internal/image_processing_utils#transformers.image_transforms.rescale.input_data_format) parameter to assign the channel dimension.
# The channel dimension is ambiguous. Got image shape (1, 1, 3). Assuming channels are the first dimension. Use the [input_data_format](https://huggingface.co/docs/transformers/main/internal/image_processing_utils#transformers.image_transforms.rescale.input_data_format) parameter to assign the channel dimension.
# The channel dimension is ambiguous. Got image shape (1, 1, 3). Assuming channels are the first dimension. Use the [input_data_format](https://huggingface.co/docs/transformers/main/internal/image_processing_utils#transformers.image_transforms.rescale.input_data_format) parameter to assign the channel dimension.
#   Error processing 1076-NRJS-1c1fad81c961ed3a045: image file is truncated (0 bytes not processed)
#
#   Error processing 1065-registration: mean must have 1 elements if it is an iterable, got 3
#
#   Error processing 1068-c.gif: mean must have 1 elements if it is an iterable, got 3
#
#   Error processing 1073-NRJS-1c1fad81c961ed3a045: image file is truncated (0 bytes not processed)
#
#   Error processing 1074-NRJS-1c1fad81c961ed3a045: image file is truncated (0 bytes not processed)
#
#   Error processing 1077-NRJS-1c1fad81c961ed3a045: image file is truncated (0 bytes not processed)
#
#   Error processing 1078-blobs: image file is truncated (0 bytes not processed)
#
#   Error processing 1066-c.gif: mean must have 1 elements if it is an iterable, got 3
#
#   Error processing 1075-blobs: image file is truncated (0 bytes not processed)
#   Results:
#     Exterior: 311 images
#     Interior: 282 images
#     Others:   577 images
#     Total:    1170 images
#
# ======================================================================
# PROCESSING COMPLETE - SUMMARY
# ======================================================================
#
# Processed 7 model folders:
#   Total Exterior: 4239 images
#   Total Interior: 1024 images
#   Total Others:   1446 images
#   Grand Total:    6709 images
#
# Breakdown by model:
# ----------------------------------------------------------------------
# nixon-ev                                 | Ext: 404 | Int:  69 | Oth: 128 | Total: 601
# harrier                                  | Ext: 597 | Int: 520 | Oth: 122 | Total: 1239
# nixon                                    | Ext: 700 | Int:  21 | Oth: 182 | Total: 903
# Harrier                                  | Ext: 1348 | Int:  45 | Oth: 197 | Total: 1590
# curvv                                    | Ext: 449 | Int:  11 | Oth:  87 | Total: 547
# curv-ev                                  | Ext: 430 | Int:  76 | Oth: 153 | Total: 659
# altroz                                   | Ext: 311 | Int: 282 | Oth: 577 | Total: 1170
#
# ======================================================================
# All classified images saved to: TATA1/
#  Each model has its own subfolder with Exterior/Interior/Others
#  Check 'classification_log.json' in each folder for details
# ======================================================================

# %%
# !rm -rf Force

# %%
import os
import shutil

def flatten_model_folders(bmw_folder):
    # Iterate over each model folder in the main "bmw" directory
    for model_name in os.listdir(bmw_folder):
        model_path = os.path.join(bmw_folder, model_name)

        # Skip non-directory files
        if not os.path.isdir(model_path):
            continue

        # Traverse subdirectories of the model
        for root, dirs, files in os.walk(model_path):
            for file in files:
                src_path = os.path.join(root, file)
                dst_path = os.path.join(model_path, file)

                # Handle duplicates safely
                if os.path.exists(dst_path):
                    base, ext = os.path.splitext(file)
                    i = 1
                    while os.path.exists(dst_path):
                        dst_path = os.path.join(model_path, f"{base}_{i}{ext}")
                        i += 1

                shutil.move(src_path, dst_path)

        # Remove now-empty subfolders
        for root, dirs, _ in os.walk(model_path, topdown=False):
            for d in dirs:
                folder_path = os.path.join(root, d)
                if not os.listdir(folder_path):  # delete only if empty
                    os.rmdir(folder_path)

    print("✅ Folder restructuring complete!")

# Example usage:
flatten_model_folders("/content/drive/MyDrive/Colab Notebooks/tata1")
# Out:
# ✅ Folder restructuring complete!

# %%
# !rm -rf Citroen
